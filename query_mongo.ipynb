# %% [markdown]
# # Querying through Mongo DB

# %%
from pymongo import MongoClient
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Calling the service MongoDB

# %%
client = MongoClient("localhost:27017")

# %%
db = client["Ironhack"]

# %%
comp = db.get_collection("companies")

# %% [markdown]
# ### Regex for names, categories, tags, description

# %% [markdown]
# - Conditions

# %%
companies_name = {'name':
                        {"$regex": 
                        '^(design|ux|ui|design|frontend|backend|gaming|game|gamer|web|develop|software)',
                        "$options" :'i'}}

# %%
companies_cat = {'category_code':
                        {"$regex": 
                        '^(design|ux|ui|design|frontend|backend|gaming|game|gamer|web|develop|software)',
                        "$options" :'i'}}

# %%
companies_tag = {'tag_list':
                        {"$regex": 
                        '^(design|ux|ui|design|frontend|backend|gaming|game|gamer|web|develop|software)',
                        "$options" :'i'}}

# %%
companies_desc = {'description':
                         {"$regex": 
                        '^(design|ux|ui|design|frontend|backend|gaming|game|gamer|web|develop|software)',
                        "$options" :'i'}}

# %%
companies_overview ={'overview':
                        {"$regex": 
                        '^(design|ux|ui|design|frontend|backend|gaming|game|gamer|web|develop|software)',
                        "$options" :'i'}}

# %% [markdown]
# -  Filter

# %%
filter_ = {
            "$or": [companies_name, companies_cat, companies_tag, companies_desc, companies_overview]
            }

# %% [markdown]
# - get the names of the companies filtered

# %%
projection = {'name': 1,
              'offices.city':1,
              'offices.country_code':1,
              'offices.latitude':1, 
              'offices.longitude':1,
              'acquisition.price_amount':1,              
              '_id': 0}

# %%
filt_list = list(comp.find(filter_, projection))
filt_list
# Out:
# [{'name': 'Wetpaint',
#   'acquisition': {'price_amount': 30000000},
#   'offices': [{'city': 'Seattle',
#     'country_code': 'USA',
#     'latitude': 47.603122,
#     'longitude': -122.333253},
#    {'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.7237306,
#     'longitude': -73.9964312}]},
#  {'name': 'Zoho',
#   'offices': [{'city': 'Pleasanton',
#     'country_code': 'USA',
#     'latitude': 37.692934,
#     'longitude': -121.904945}]},
#  {'name': 'Postini',
#   'acquisition': {'price_amount': 625000000},
#   'offices': [{'city': 'San Carlos',
#     'country_code': 'USA',
#     'latitude': 37.506885,
#     'longitude': -122.247573}]},
#  {'name': 'Geni',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'West Hollywood',
#     'country_code': 'USA',
#     'latitude': 34.090368,
#     'longitude': -118.393064}]},
#  {'name': 'Flektor',
#   'acquisition': {'price_amount': 20000000},
#   'offices': [{'city': 'Culver City',
#     'country_code': 'USA',
#     'latitude': 34.025958,
#     'longitude': -118.379768}]},
#  {'name': 'Fox Interactive Media',
#   'offices': [{'city': 'Beverly Hills',
#     'country_code': 'USA',
#     'latitude': 34.076179,
#     'longitude': -118.39417}]},
#  {'name': 'StumbleUpon',
#   'acquisition': {'price_amount': 29000000},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.775196,
#     'longitude': -122.419204},
#    {'city': 'New York City',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Gizmoz',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Menlo Park',
#     'country_code': 'USA',
#     'latitude': 37.48413,
#     'longitude': -122.169472}]},
#  {'name': 'Lala',
#   'acquisition': {'price_amount': 80000000},
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.451151,
#     'longitude': -122.154369}]},
#  {'name': 'eBay',
#   'offices': [{'city': 'San Jose',
#     'country_code': 'USA',
#     'latitude': 37.295005,
#     'longitude': -121.930035}]},
#  {'name': 'Joost',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.7464969,
#     'longitude': -74.0094471}]},
#  {'name': 'Viacom',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.757725,
#     'longitude': -73.986011}]},
#  {'name': 'Babelgum',
#   'offices': [{'city': 'London',
#     'country_code': 'GBR',
#     'latitude': 53.344104,
#     'longitude': -6.267494}]},
#  {'name': 'Plaxo',
#   'acquisition': {'price_amount': 150000000},
#   'offices': [{'city': 'Sunnyvale',
#     'country_code': 'USA',
#     'latitude': 37.387845,
#     'longitude': -122.055197}]},
#  {'name': 'Yahoo!',
#   'offices': [{'city': 'Sunnyvale',
#     'country_code': 'USA',
#     'latitude': 37.418531,
#     'longitude': -122.025485}]},
#  {'name': 'Mahalo',
#   'offices': [{'city': 'Culver City',
#     'country_code': 'USA',
#     'latitude': 34.017606,
#     'longitude': -118.487267}]},
#  {'name': 'Sparter',
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'Kyte',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.788482,
#     'longitude': -122.409173}]},
#  {'name': 'Veoh',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Diego',
#     'country_code': 'USA',
#     'latitude': 32.902266,
#     'longitude': -117.20834}]},
#  {'name': 'Gannett',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'McLean',
#     'country_code': 'USA',
#     'latitude': 38.929289,
#     'longitude': -77.216585}]},
#  {'name': 'Thoof',
#   'offices': [{'city': 'Austin',
#     'country_code': 'USA',
#     'latitude': 30.268735,
#     'longitude': -97.745209}]},
#  {'name': 'Info',
#   'offices': [{'city': 'Chicago',
#     'country_code': 'USA',
#     'latitude': 41.885619,
#     'longitude': -87.622309}]},
#  {'name': 'JotSpot',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.437328,
#     'longitude': -122.159928}]},
#  {'name': 'Meetup',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.72604,
#     'longitude': -73.995722}]},
#  {'name': 'Mercora',
#   'offices': [{'city': 'Sunnyvale',
#     'country_code': 'USA',
#     'latitude': 37.384239,
#     'longitude': -122.012475}]},
#  {'name': 'NetRatings',
#   'acquisition': {'price_amount': 327000000},
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'Wesabe',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.793148,
#     'longitude': -122.402567}]},
#  {'name': 'Jangl SMS',
#   'offices': [{'city': 'Pleasanton',
#     'country_code': 'USA',
#     'latitude': 37.697805,
#     'longitude': -121.907768}]},
#  {'name': 'Skype',
#   'acquisition': {'price_amount': 2600000000},
#   'offices': [{'city': 'Luxembourg City',
#     'country_code': 'LUX',
#     'latitude': 51.518132,
#     'longitude': -0.131916},
#    {'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'London',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'YouTube',
#   'acquisition': {'price_amount': 1650000000},
#   'offices': [{'city': 'San Bruno',
#     'country_code': 'USA',
#     'latitude': 37.627971,
#     'longitude': -122.426804}]},
#  {'name': 'Stickam',
#   'offices': [{'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': 34.051409,
#     'longitude': -118.254558}]},
#  {'name': 'blogTV',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Ramat Gan',
#     'country_code': 'ISR',
#     'latitude': 31.046051,
#     'longitude': 34.851612}]},
#  {'name': 'Livestream',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.726155,
#     'longitude': -73.995625}]},
#  {'name': 'Ustream',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.392936,
#     'longitude': -122.07948},
#    {'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Budapest',
#     'country_code': 'HUN',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'AdaptiveBlue',
#   'offices': [{'city': 'NYC',
#     'country_code': 'USA',
#     'latitude': 40.801358,
#     'longitude': -74.3372}]},
#  {'name': 'Pando Networks',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.722655,
#     'longitude': -73.99873}]},
#  {'name': 'Ikan',
#   'offices': [{'city': 'Stamford',
#     'country_code': 'USA',
#     'latitude': 41.049051,
#     'longitude': -73.563878}]},
#  {'name': 'delicious',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Mateo',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Topix',
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.44296,
#     'longitude': -122.151198}]},
#  {'name': 'Pownce',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.762541,
#     'longitude': -122.397224}]},
#  {'name': 'Revision3',
#   'acquisition': {'price_amount': 30000000},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.757758,
#     'longitude': -122.388243}]},
#  {'name': 'AllPeers',
#   'offices': [{'city': 'Oxford',
#     'country_code': 'GBR',
#     'latitude': 51.752276,
#     'longitude': -1.255824}]},
#  {'name': 'CriticalMetrics',
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.269175,
#     'longitude': -119.306607}]},
#  {'name': 'SodaHead',
#   'offices': [{'city': 'Encino',
#     'country_code': 'USA',
#     'latitude': 37.269175,
#     'longitude': -119.306607}]},
#  {'name': 'CastTV',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.780716,
#     'longitude': -122.393913}]},
#  {'name': 'AllofMP3',
#   'offices': [{'city': 'Moscow',
#     'country_code': 'RUS',
#     'latitude': 55.755786,
#     'longitude': 37.617633}]},
#  {'name': 'There',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Mateo',
#     'country_code': 'USA',
#     'latitude': 37.553385,
#     'longitude': -122.302149}]},
#  {'name': 'SellABand',
#   'offices': [{'city': '46395 Bocholt',
#     'country_code': 'DEU',
#     'latitude': 51.808933,
#     'longitude': 6.553452}]},
#  {'name': 'Funny Or Die',
#   'offices': [{'city': 'San Mateo',
#     'country_code': 'USA',
#     'latitude': 37.421621,
#     'longitude': -122.137444}]},
#  {'name': 'Steorn',
#   'offices': [{'city': 'Dublin',
#     'country_code': 'IRL',
#     'latitude': 53.354997,
#     'longitude': -6.229255}]},
#  {'name': 'MeeVee',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Burlingame',
#     'country_code': 'USA',
#     'latitude': 37.590339,
#     'longitude': -122.341715}]},
#  {'name': 'blinkx',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.793819,
#     'longitude': -122.395089}]},
#  {'name': 'ClipBlast!',
#   'offices': [{'city': 'Agoura Hills',
#     'country_code': 'USA',
#     'latitude': 34.155211,
#     'longitude': -118.756618}]},
#  {'name': 'Tun3r',
#   'offices': [{'city': 'Toronto, Ontario',
#     'country_code': 'CAN',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Spotplex',
#   'offices': [{'city': 'Santa Clara',
#     'country_code': 'USA',
#     'latitude': 37.380101,
#     'longitude': -121.940749}]},
#  {'name': 'TripUp',
#   'offices': [{'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'Wakoopa',
#   'offices': [{'city': 'Amsterdam',
#     'country_code': 'NLD',
#     'latitude': 52.3745228,
#     'longitude': 4.8948623}]},
#  {'name': 'Fleck',
#   'offices': [{'city': 'Amsterdam',
#     'country_code': 'NLD',
#     'latitude': 52.375595,
#     'longitude': 4.908556}]},
#  {'name': 'Coghead',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Redwood City',
#     'country_code': 'USA',
#     'latitude': 37.476479,
#     'longitude': -122.221717}]},
#  {'name': 'Zamzar',
#   'offices': [{'city': 'Southampton',
#     'country_code': 'GBR',
#     'latitude': 50.9444598,
#     'longitude': -1.3610845}]},
#  {'name': 'Zooomr',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.775196,
#     'longitude': -122.419204}]},
#  {'name': 'SideStep',
#   'acquisition': {'price_amount': 180000000},
#   'offices': [{'city': 'Santa Clara',
#     'country_code': 'USA',
#     'latitude': 37.374998,
#     'longitude': -121.977853}]},
#  {'name': 'coRank',
#   'offices': [{'city': 'Sunnyvale',
#     'country_code': 'USA',
#     'latitude': 37.36965,
#     'longitude': -122.02421}]},
#  {'name': 'RockYou',
#   'offices': [{'city': 'Redwood City',
#     'country_code': 'USA',
#     'latitude': 37.484619,
#     'longitude': -122.206893}]},
#  {'name': 'Pageflakes',
#   'acquisition': {'price_amount': 3000000},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.758113,
#     'longitude': -122.414689}]},
#  {'name': 'Instructables',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.7791761,
#     'longitude': -122.4058887}]},
#  {'name': 'Netvibes',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Paris',
#     'country_code': 'FRA',
#     'latitude': 48.870806,
#     'longitude': 2.34668},
#    {'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Slide',
#   'acquisition': {'price_amount': 182000000},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.781427,
#     'longitude': -122.392144}]},
#  {'name': 'Bebo',
#   'acquisition': {'price_amount': 10000000},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.782103,
#     'longitude': -122.401116}]},
#  {'name': 'Flickr',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Sunnyvale',
#     'country_code': 'USA',
#     'latitude': 37.418531,
#     'longitude': -122.025485}]},
#  {'name': 'BabyCenter',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.778076,
#     'longitude': -122.397977}]},
#  {'name': 'PlaceBlogger',
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'TripHub',
#   'offices': [{'city': 'Seattle',
#     'country_code': 'USA',
#     'latitude': 47.614653,
#     'longitude': -122.338793}]},
#  {'name': 'CrowdVine',
#   'offices': [{'city': 'Mill Valley',
#     'country_code': 'USA',
#     'latitude': 37.90077,
#     'longitude': -122.511687}]},
#  {'name': 'FeedBurner',
#   'acquisition': {'price_amount': 100000000},
#   'offices': [{'city': 'Chicago',
#     'country_code': 'USA',
#     'latitude': 41.889474,
#     'longitude': -87.628912}]},
#  {'name': 'TVtrip',
#   'offices': [{'city': 'Paris',
#     'country_code': 'FRA',
#     'latitude': 48.856667,
#     'longitude': 2.350987}]},
#  {'name': 'Dogster',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.762681,
#     'longitude': -122.400909}]},
#  {'name': 'WatZatSong',
#   'offices': [{'city': 'Paris',
#     'country_code': 'FRA',
#     'latitude': 48.866323,
#     'longitude': 2.381514}]},
#  {'name': 'Loomia',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.796396,
#     'longitude': -122.404869}]},
#  {'name': 'Meebo',
#   'acquisition': {'price_amount': 100000000},
#   'offices': [{'city': 'Mountain View',
#     'country_code': 'USA',
#     'latitude': 37.393679,
#     'longitude': -122.079017},
#    {'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Santa Monica',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'New York',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Chicago',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Eventbrite',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.779507,
#     'longitude': -122.39071}]},
#  {'name': 'Newsvine',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Seattle',
#     'country_code': 'USA',
#     'latitude': 47.618599,
#     'longitude': -122.358484}]},
#  {'name': 'Terabitz',
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.437328,
#     'longitude': -122.159928}]},
#  {'name': 'iLike',
#   'acquisition': {'price_amount': 20000000},
#   'offices': [{'city': 'Seattle',
#     'country_code': 'USA',
#     'latitude': 47.615313,
#     'longitude': -122.323408}]},
#  {'name': 'Ticketmaster',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'West Hollywood',
#     'country_code': 'USA',
#     'latitude': 34.0906602,
#     'longitude': -118.3835957}]},
#  {'name': 'Cuts',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Diego',
#     'country_code': 'USA',
#     'latitude': 32.718834,
#     'longitude': -117.163841}]},
#  {'name': 'Go2Web20',
#   'offices': [{'city': 'Tel Aviv',
#     'country_code': 'ISR',
#     'latitude': 32.0554,
#     'longitude': 34.7595}]},
#  {'name': 'coComment',
#   'offices': [{'city': 'Geneva',
#     'country_code': 'CHE',
#     'latitude': 46.20381,
#     'longitude': 6.139959}]},
#  {'name': 'Seesmic',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.775196,
#     'longitude': -122.419204}]},
#  {'name': 'TechnologyGuide',
#   'acquisition': {'price_amount': 15000000},
#   'offices': [{'city': 'Cincinnati',
#     'country_code': 'USA',
#     'latitude': 39.06685,
#     'longitude': -84.351532}]},
#  {'name': 'Hotelicopter',
#   'offices': [{'city': 'Charlottesville',
#     'country_code': 'USA',
#     'latitude': 38.030823,
#     'longitude': -78.48158}]},
#  {'name': 'Zvents',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Mateo',
#     'country_code': 'USA',
#     'latitude': 37.553121,
#     'longitude': -122.301534}]},
#  {'name': 'MotionDSP',
#   'offices': [{'city': 'Burlingame',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Techmeme',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.7618242,
#     'longitude': -122.3985871}]},
#  {'name': 'Eventful',
#   'offices': [{'city': 'San Diego',
#     'country_code': 'USA',
#     'latitude': 32.872081,
#     'longitude': -117.206292},
#    {'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'RegOnline',
#   'offices': [{'city': 'San Diego',
#     'country_code': 'USA',
#     'latitude': 39.9195028,
#     'longitude': -105.1110024}]},
#  {'name': 'oDesk',
#   'offices': [{'city': 'Redwood City',
#     'country_code': 'USA',
#     'latitude': 37.479952,
#     'longitude': -122.178557}]},
#  {'name': 'Scripps Networks Interactive',
#   'offices': [{'city': 'Knoxville',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'Ujogo',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.76785,
#     'longitude': -122.392861}]},
#  {'name': 'Recipezaar',
#   'acquisition': {'price_amount': 25000000},
#   'offices': [{'city': 'Vashon',
#     'country_code': 'USA',
#     'latitude': 47.420728,
#     'longitude': -122.450942}]},
#  {'name': 'Gumiyo',
#   'offices': [{'city': 'Woodland Hills',
#     'country_code': 'USA',
#     'latitude': 34.184598,
#     'longitude': -118.601532}]},
#  {'name': 'stylediary',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': 34.070436,
#     'longitude': -118.350486}]},
#  {'name': 'ictv',
#   'offices': [{'city': 'Los Gatos',
#     'country_code': 'USA',
#     'latitude': 37.255118,
#     'longitude': -121.96533}]},
#  {'name': 'GoingOn',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.782263,
#     'longitude': -122.392142}]},
#  {'name': 'Flixster',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.766909,
#     'longitude': -122.406676}]},
#  {'name': 'MyPublicInfo',
#   'offices': [{'city': 'Arlington',
#     'country_code': 'USA',
#     'latitude': 38.897428,
#     'longitude': -77.072003}]},
#  {'name': 'Checkster',
#   'offices': [{'city': 'Mill Valley',
#     'country_code': 'USA',
#     'latitude': 37.905544,
#     'longitude': -122.547445}]},
#  {'name': 'Cyworld',
#   'acquisition': {'price_amount': 7140000},
#   'offices': [{'city': 'Seoul',
#     'country_code': 'KOR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Parakey',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Mountain View',
#     'country_code': 'USA',
#     'latitude': 37.40047,
#     'longitude': -122.072981}]},
#  {'name': 'Bazaarvoice',
#   'offices': [{'city': 'Austin',
#     'country_code': 'USA',
#     'latitude': 30.407545,
#     'longitude': -97.717667}]},
#  {'name': 'spigit',
#   'offices': [{'city': 'Pleasanton',
#     'country_code': 'USA',
#     'latitude': 37.6637279,
#     'longitude': -121.8731805},
#    {'city': 'Reston',
#     'country_code': 'USA',
#     'latitude': 38.9590083,
#     'longitude': -77.3592746},
#    {'city': 'London',
#     'country_code': 'GBR',
#     'latitude': 51.5170385,
#     'longitude': -0.1394759}]},
#  {'name': 'ConnectMeAnywhere',
#   'offices': [{'city': 'London W11 2HX',
#     'country_code': 'GBR',
#     'latitude': 51.514935,
#     'longitude': -0.205349}]},
#  {'name': 'LiveWorld',
#   'offices': [{'city': 'San Jose',
#     'country_code': 'USA',
#     'latitude': 37.321798,
#     'longitude': -121.979453},
#    {'city': 'London',
#     'country_code': 'GBR',
#     'latitude': 51.500152,
#     'longitude': -0.126236}]},
#  {'name': 'Ohloh',
#   'acquisition': {'price_amount': 3000000},
#   'offices': [{'city': 'Bellevue',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'hi5',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.788668,
#     'longitude': -122.400558}]},
#  {'name': 'Clipperz',
#   'offices': [{'city': 'Bagnacavallo',
#     'country_code': 'ITA',
#     'latitude': 44.418166,
#     'longitude': 11.978686}]},
#  {'name': 'Nintendo',
#   'offices': [{'city': None,
#     'country_code': 'JPN',
#     'latitude': 36.204824,
#     'longitude': 138.252924}]},
#  {'name': 'Indeed',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Stamford',
#     'country_code': 'USA',
#     'latitude': 41.038155,
#     'longitude': -73.558082},
#    {'city': 'Austin',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Cerado',
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.774321,
#     'longitude': -122.415375}]},
#  {'name': 'introNetworks',
#   'offices': [{'city': 'Montecito',
#     'country_code': 'USA',
#     'latitude': 34.42071,
#     'longitude': -119.641821}]},
#  {'name': 'Kwiqq',
#   'offices': [{'city': 'Brighton',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Going',
#   'acquisition': {'price_amount': 10000000},
#   'offices': [{'city': 'Boston',
#     'country_code': 'USA',
#     'latitude': 42.355672,
#     'longitude': -71.060864}]},
#  {'name': 'Respectance',
#   'offices': [{'city': 'San Mateo',
#     'country_code': 'USA',
#     'latitude': 37.55909,
#     'longitude': -122.321836}]},
#  {'name': 'Curse',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.787092,
#     'longitude': -122.399972},
#    {'city': 'Huntsville',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Jaman',
#   'offices': [{'city': 'San Mateo',
#     'country_code': 'USA',
#     'latitude': 37.536172,
#     'longitude': -122.327323}]},
#  {'name': 'GoLightly',
#   'offices': [{'city': 'Mill Valley',
#     'country_code': 'USA',
#     'latitude': 37.898575,
#     'longitude': -122.537302}]},
#  {'name': 'eBuddy',
#   'offices': [{'city': 'Amsterdam',
#     'country_code': 'NLD',
#     'latitude': 52.3640933,
#     'longitude': 4.8919457},
#    {'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.787683,
#     'longitude': -122.410943},
#    {'city': 'Singapore',
#     'country_code': 'SGP',
#     'latitude': 51.500152,
#     'longitude': -0.126236}]},
#  {'name': 'DZOIC',
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'PeerMe',
#   'offices': [{'city': 'Mountain View',
#     'country_code': 'USA',
#     'latitude': 37.419819,
#     'longitude': -122.090188}]},
#  {'name': 'Adobe Systems',
#   'offices': [{'city': 'San Jose',
#     'country_code': 'USA',
#     'latitude': 37.320052,
#     'longitude': -121.877636}]},
#  {'name': 'CollegeWikis',
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'FeVote',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.779392,
#     'longitude': -122.417928}]},
#  {'name': 'Vuze',
#   'offices': [{'city': 'San Mateo',
#     'country_code': 'USA',
#     'latitude': 37.4858654,
#     'longitude': -122.2262606}]},
#  {'name': 'JumpBox',
#   'offices': [{'city': 'Phoenix',
#     'country_code': 'USA',
#     'latitude': 33.429864,
#     'longitude': -111.944967}]},
#  {'name': 'Phonezoo',
#   'offices': [{'city': 'Sunnyvale',
#     'country_code': 'USA',
#     'latitude': 37.386376,
#     'longitude': -121.991471}]},
#  {'name': 'Relationals',
#   'offices': [{'city': 'Sunnyvale',
#     'country_code': 'USA',
#     'latitude': 37.384651,
#     'longitude': -121.992132}]},
#  {'name': 'Truemors',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.446687,
#     'longitude': -122.163189}]},
#  {'name': 'Nononina',
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': 37.269175,
#     'longitude': -119.306607}]},
#  {'name': 'PodTech',
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.408256,
#     'longitude': -122.154176}]},
#  {'name': 'NowPublic',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Vancouver',
#     'country_code': 'CAN',
#     'latitude': 49.283376,
#     'longitude': -123.103986}]},
#  {'name': 'PayScale',
#   'offices': [{'city': 'Seattle',
#     'country_code': 'USA',
#     'latitude': 47.5999337,
#     'longitude': -122.3276962}]},
#  {'name': 'Crackle',
#   'offices': [{'city': 'Culver City',
#     'country_code': 'USA',
#     'latitude': 34.017506,
#     'longitude': -118.401579}]},
#  {'name': 'Forbes',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.736416,
#     'longitude': -73.993302}]},
#  {'name': 'Boonex',
#   'offices': [{'city': 'Sydney',
#     'country_code': 'AUS',
#     'latitude': -33.722577,
#     'longitude': 150.981801}]},
#  {'name': 'IntenseDebate',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Boulder',
#     'country_code': 'USA',
#     'latitude': 40.010492,
#     'longitude': -105.276843}]},
#  {'name': 'Reddit',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.780883,
#     'longitude': -122.395257}]},
#  {'name': 'Wikia',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'BuddyTV',
#   'offices': [{'city': 'Seattle',
#     'country_code': 'USA',
#     'latitude': 47.61968,
#     'longitude': -122.356756}]},
#  {'name': 'Retrevo',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Sunnyvale',
#     'country_code': 'USA',
#     'latitude': 37.368594,
#     'longitude': -122.034021}]},
#  {'name': 'Buxfer',
#   'offices': [{'city': 'Mountain View',
#     'country_code': 'USA',
#     'latitude': 37.400465,
#     'longitude': -122.073003}]},
#  {'name': 'Tangler',
#   'offices': [{'city': 'Mountain View',
#     'country_code': 'USA',
#     'latitude': 37.386665,
#     'longitude': -122.084171}]},
#  {'name': 'TextPayMe',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Redmond',
#     'country_code': 'USA',
#     'latitude': 47.672229,
#     'longitude': -122.115633}]},
#  {'name': 'BillMonk',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Seattle',
#     'country_code': 'USA',
#     'latitude': 47.620716,
#     'longitude': -122.347533}]},
#  {'name': 'TalkPlus',
#   'offices': [{'city': 'San Mateo',
#     'country_code': 'USA',
#     'latitude': 37.553743,
#     'longitude': -122.300246}]},
#  {'name': 'MeeMix',
#   'offices': [{'city': 'Tel Aviv',
#     'country_code': 'ISR',
#     'latitude': 32.0554,
#     'longitude': 34.7595}]},
#  {'name': 'Citizenbay',
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'The Walt Disney Company',
#   'offices': [{'city': 'Burbank',
#     'country_code': 'USA',
#     'latitude': 34.156802,
#     'longitude': -118.324987}]},
#  {'name': 'Alstrasoft',
#   'offices': [{'city': 'Singapore',
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'PermissionTV',
#   'offices': [{'city': 'Waltham',
#     'country_code': 'USA',
#     'latitude': 42.417268,
#     'longitude': -71.258466}]},
#  {'name': 'WebbAlert',
#   'offices': [{'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'WallStrip',
#   'acquisition': {'price_amount': 5000000},
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'Citysearch',
#   'offices': [{'city': 'West Hollywood',
#     'country_code': 'USA',
#     'latitude': 34.090932,
#     'longitude': -118.38428}]},
#  {'name': 'AOL',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.7311317,
#     'longitude': -73.9919311}]},
#  {'name': 'Hewlett-Packard',
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.437328,
#     'longitude': -122.159928},
#    {'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Mattel',
#   'offices': [{'city': 'El Segundo',
#     'country_code': 'USA',
#     'latitude': 33.920296,
#     'longitude': -118.391852}]},
#  {'name': 'Kaneva',
#   'offices': [{'city': 'Atlanta',
#     'country_code': 'USA',
#     'latitude': 33.916374,
#     'longitude': -84.350663}]},
#  {'name': 'IMVU',
#   'offices': [{'city': 'Mountain View',
#     'country_code': 'USA',
#     'latitude': 37.3927975,
#     'longitude': -122.0727749}]},
#  {'name': 'madKast',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Boulder',
#     'country_code': 'USA',
#     'latitude': 40.010492,
#     'longitude': -105.276843}]},
#  {'name': 'Aniboom',
#   'offices': [{'city': None,
#     'country_code': 'ISR',
#     'latitude': 31.046051,
#     'longitude': 34.851612}]},
#  {'name': 'Meetro',
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.437328,
#     'longitude': -122.159928}]},
#  {'name': 'Webkinz',
#   'offices': [{'city': 'Woodbridge',
#     'country_code': 'CAN',
#     'latitude': 43.76969,
#     'longitude': -79.549577}]},
#  {'name': 'Zwinky',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'MyToons',
#   'offices': [{'city': 'San Antonio',
#     'country_code': 'USA',
#     'latitude': 29.427051,
#     'longitude': -98.487764}]},
#  {'name': 'Mokitown',
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'ActiveWorlds',
#   'offices': [{'city': 'Newburyport',
#     'country_code': 'USA',
#     'latitude': 42.7973978,
#     'longitude': -70.8873327},
#    {'city': 'Las Vegas',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Sulake',
#   'offices': [{'city': 'Helsinki',
#     'country_code': 'FIN',
#     'latitude': 60.165166,
#     'longitude': 24.945937}]},
#  {'name': 'Neopets',
#   'acquisition': {'price_amount': 160000000},
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'Dubit',
#   'offices': [{'city': 'Leeds',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'KnockaTV',
#   'offices': [{'city': '',
#     'country_code': 'ISR',
#     'latitude': 31.046051,
#     'longitude': 34.851612}]},
#  {'name': 'Faketown',
#   'offices': [{'city': 'Venice',
#     'country_code': 'USA',
#     'latitude': 33.988337,
#     'longitude': -118.472721}]},
#  {'name': 'Millsberry',
#   'offices': [{'city': 'mem',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'INgage Networks',
#   'offices': [{'city': 'Naples',
#     'country_code': 'USA',
#     'latitude': 26.246414,
#     'longitude': -81.788104},
#    {'city': 'Atlanta',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Omnifuse',
#   'offices': [{'city': 'Newport Beach',
#     'country_code': 'USA',
#     'latitude': 33.610083,
#     'longitude': -117.928351}]},
#  {'name': 'Pickle',
#   'acquisition': {'price_amount': 4100000},
#   'offices': [{'city': 'Arlington',
#     'country_code': 'USA',
#     'latitude': 38.892371,
#     'longitude': -77.081732}]},
#  {'name': 'Strayform',
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 31.169036,
#     'longitude': -100.076888}]},
#  {'name': 'Revver',
#   'acquisition': {'price_amount': 5000000},
#   'offices': [{'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'HireAHelper',
#   'offices': [{'city': 'Oceanside',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Metacafe',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.437328,
#     'longitude': -122.159928}]},
#  {'name': 'Flock',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Menlo Park',
#     'country_code': 'USA',
#     'latitude': 37.491356,
#     'longitude': -122.228843}]},
#  {'name': 'Social Platform',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': 34.101617,
#     'longitude': -118.327071}]},
#  {'name': 'webcrossing',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.794649,
#     'longitude': -122.399646}]},
#  {'name': 'Sportingo',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': None,
#     'country_code': 'ISR',
#     'latitude': 17.08881,
#     'longitude': -96.76492}]},
#  {'name': 'Dropbox',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.7909427,
#     'longitude': -122.4084994},
#    {'city': 'Dublin',
#     'country_code': 'IRL',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Splashup',
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'TimeBridge',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Mountain View',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Yoomba',
#   'offices': [{'city': 'Menlo Park',
#     'country_code': 'USA',
#     'latitude': 37.48413,
#     'longitude': -122.169472}]},
#  {'name': 'Negonation',
#   'offices': [{'city': '',
#     'country_code': 'ESP',
#     'latitude': 40.463667,
#     'longitude': -3.74922}]},
#  {'name': 'Snocap',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'IODA',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.780134,
#     'longitude': -122.396744}]},
#  {'name': 'TokBox',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.779507,
#     'longitude': -122.39071},
#    {'city': 'Ultimo',
#     'country_code': 'AUS',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'New York',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Barcelona, 08019',
#     'country_code': 'ESP',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Jimdo',
#   'offices': [{'city': 'Hamburg',
#     'country_code': 'DEU',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Tokyo',
#     'country_code': 'JPN',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Shanghai',
#     'country_code': 'CHN',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'MDJunction',
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Sampa',
#   'offices': [{'city': 'Redmond',
#     'country_code': 'USA',
#     'latitude': 47.682233,
#     'longitude': -122.135521}]},
#  {'name': 'Weebly',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.795555,
#     'longitude': -122.400729}]},
#  {'name': 'Yola',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.7911148,
#     'longitude': -122.3954751},
#    {'city': 'Cape Town',
#     'country_code': 'ZAF',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'RealEditor',
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 38.805114,
#     'longitude': -77.236968}]},
#  {'name': 'BitTorrent',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.790998,
#     'longitude': -122.394668}]},
#  {'name': 'Kongregate',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.786942,
#     'longitude': -122.401245}]},
#  {'name': 'DanceJam',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.781557,
#     'longitude': -122.407959}]},
#  {'name': 'Filtrbox',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 40.010492,
#     'longitude': -105.276843}]},
#  {'name': 'Eventbee',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.383779,
#     'longitude': -122.007172}]},
#  {'name': 'SlapVid',
#   'offices': [{'city': 'Pittsburgh',
#     'country_code': 'USA',
#     'latitude': 40.445009,
#     'longitude': -79.948563}]},
#  {'name': 'Veotag',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.752957,
#     'longitude': -73.98546}]},
#  {'name': 'Guba',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'GoFish',
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'Digitalsmiths',
#   'offices': [{'city': 'Durham',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'PartnerUp',
#   'acquisition': {'price_amount': 3800000},
#   'offices': [{'city': 'Minneapolis',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Hitwise',
#   'acquisition': {'price_amount': 240000000},
#   'offices': [{'city': 'Melbourne',
#     'country_code': 'AUS',
#     'latitude': -37.814251,
#     'longitude': 144.963169}]},
#  {'name': 'Jambo',
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'SuicideGirls',
#   'offices': [{'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': 34.062262,
#     'longitude': -118.348198}]},
#  {'name': 'Goowy',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Diego',
#     'country_code': 'USA',
#     'latitude': 32.71537,
#     'longitude': -117.163353}]},
#  {'name': 'Jooce',
#   'offices': [{'city': 'Paris',
#     'country_code': 'FRA',
#     'latitude': 48.856667,
#     'longitude': 2.350987}]},
#  {'name': 'A9',
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.444554,
#     'longitude': -122.164511}]},
#  {'name': 'Doostang',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.427235,
#     'longitude': -122.145783}]},
#  {'name': 'JumpTV',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.705898,
#     'longitude': -74.011398}]},
#  {'name': 'Helium',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Andover',
#     'country_code': 'USA',
#     'latitude': 42.675189,
#     'longitude': -71.1469}]},
#  {'name': 'Zappos',
#   'acquisition': {'price_amount': 1200000000},
#   'offices': [{'city': 'Henderson',
#     'country_code': 'USA',
#     'latitude': 36.032976,
#     'longitude': -115.064859},
#    {'city': 'Shepherdsville',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Zango',
#   'offices': [{'city': 'Bellevue',
#     'country_code': 'USA',
#     'latitude': 47.579208,
#     'longitude': -122.155668}]},
#  {'name': 'Docstoc',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Santa Monica',
#     'country_code': 'USA',
#     'latitude': 34.018275,
#     'longitude': -118.495025}]},
#  {'name': 'DotBlu',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'Mevio',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.782263,
#     'longitude': -122.392142}]},
#  {'name': 'Ruckus',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'Shock Treatment Management',
#   'offices': [{'city': 'Seattle',
#     'country_code': 'USA',
#     'latitude': 47.610332,
#     'longitude': -122.339859}]},
#  {'name': 'Pluck',
#   'acquisition': {'price_amount': 75000000},
#   'offices': [{'city': 'Austin',
#     'country_code': 'USA',
#     'latitude': 30.268735,
#     'longitude': -97.745209}]},
#  {'name': 'FilmLoop',
#   'offices': [{'city': 'Menlo Park',
#     'country_code': 'USA',
#     'latitude': 37.48413,
#     'longitude': -122.169472}]},
#  {'name': 'BitPass',
#   'offices': [{'city': 'Mountain View',
#     'country_code': 'USA',
#     'latitude': 37.40047,
#     'longitude': -122.072981}]},
#  {'name': 'Musicmatch',
#   'acquisition': {'price_amount': 160000000},
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'sezmi',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Belmont',
#     'country_code': 'USA',
#     'latitude': 37.524422,
#     'longitude': -122.265869},
#    {'city': 'Santa Monica',
#     'country_code': 'USA',
#     'latitude': 34.017373,
#     'longitude': -118.453218},
#    {'city': 'Fort Lauderdale',
#     'country_code': 'USA',
#     'latitude': 26.207024,
#     'longitude': -80.157296}]},
#  {'name': 'Atom Entertainment',
#   'acquisition': {'price_amount': 200000000},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.790964,
#     'longitude': -122.401128}]},
#  {'name': 'CinemaNow',
#   'offices': [{'city': 'Marina Del Rey',
#     'country_code': 'USA',
#     'latitude': 33.983543,
#     'longitude': -118.432526}]},
#  {'name': 'eHarmony',
#   'offices': [{'city': 'Santa Monica',
#     'country_code': 'USA',
#     'latitude': 34.145946,
#     'longitude': -118.132351}]},
#  {'name': 'Friendster',
#   'acquisition': {'price_amount': 26400000},
#   'offices': [{'city': 'Kuala Lumpur',
#     'country_code': 'MYS',
#     'latitude': 3.139003,
#     'longitude': 101.686855}]},
#  {'name': 'Heavy',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.753385,
#     'longitude': -73.98962}]},
#  {'name': 'Nielsen',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.731118,
#     'longitude': -73.991933}]},
#  {'name': 'Buzzmetrics',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.731118,
#     'longitude': -73.991933}]},
#  {'name': 'Exabre',
#   'offices': [{'city': 'Bath, Somerset',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'WeatherBug',
#   'offices': [{'city': 'Germantown',
#     'country_code': 'USA',
#     'latitude': 39.2009241,
#     'longitude': -77.2630048}]},
#  {'name': 'Narrowstep',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'Bix',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'Burnlounge',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.746953,
#     'longitude': -73.993553}]},
#  {'name': 'DAVE Networks',
#   'offices': [{'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': 33.979033,
#     'longitude': -118.423423},
#    {'city': 'Marina Del Rey',
#     'country_code': 'USA',
#     'latitude': 33.979506,
#     'longitude': -118.439787}]},
#  {'name': 'NexTag',
#   'offices': [{'city': 'San Mateo',
#     'country_code': 'USA',
#     'latitude': 37.554595,
#     'longitude': -122.317471}]},
#  {'name': 'Netblue',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Mountain View',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'Shopzilla',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891},
#    {'city': 'London',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'New York',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Chicago',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'dpreview',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Seattle',
#     'country_code': 'USA',
#     'latitude': 55.378051,
#     'longitude': -3.435973}]},
#  {'name': 'Sabre',
#   'acquisition': {'price_amount': 4300000000},
#   'offices': [{'city': 'Southlake',
#     'country_code': 'USA',
#     'latitude': 32.9819881,
#     'longitude': -97.1599393}]},
#  {'name': 'Lastminute',
#   'acquisition': {'price_amount': 1008000000},
#   'offices': [{'city': 'London',
#     'country_code': 'GBR',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'SpiralFrog',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'TripOvation',
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'MusicNet',
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'Cendant',
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'YellowPages',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Glendale',
#     'country_code': 'USA',
#     'latitude': 34.155224,
#     'longitude': -118.255197}]},
#  {'name': 'Vtap',
#   'offices': [{'city': 'Andover',
#     'country_code': 'USA',
#     'latitude': 42.656621,
#     'longitude': -71.140538}]},
#  {'name': 'Sportsline',
#   'acquisition': {'price_amount': 64000000},
#   'offices': [{'city': 'Fort Lauderdale',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'Digitas',
#   'acquisition': {'price_amount': 1300000000},
#   'offices': [{'city': 'Boston',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891},
#    {'city': 'Neuilly sur Seine',
#     'country_code': 'FRA',
#     'latitude': 48.882314,
#     'longitude': 2.2673953}]},
#  {'name': 'Webshots',
#   'acquisition': {'price_amount': 71000000},
#   'offices': [{'city': 'Corte Madera',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'OpenTable',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.785647,
#     'longitude': -122.405265}]},
#  {'name': 'Tickle',
#   'acquisition': {'price_amount': 93700000},
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'JobPilot',
#   'acquisition': {'price_amount': 86000000},
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'MocoSpace',
#   'offices': [{'city': 'Boston',
#     'country_code': 'USA',
#     'latitude': 42.350274,
#     'longitude': -71.058768}]},
#  {'name': 'YouBeQB',
#   'offices': [{'city': 'Bellevue',
#     'country_code': 'USA',
#     'latitude': 47.597965,
#     'longitude': -122.151158}]},
#  {'name': 'eMusic',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'RampedMedia',
#   'offices': [{'city': 'Saint Louis',
#     'country_code': 'USA',
#     'latitude': 38.618874,
#     'longitude': -90.216499}]},
#  {'name': 'Frazr',
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'PunchStock',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'GoChongo',
#   'offices': [{'city': 'Seattle',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'Minglebox',
#   'offices': [{'city': 'Bangalore',
#     'country_code': 'IND',
#     'latitude': 12.971606,
#     'longitude': 77.594376}]},
#  {'name': 'MyZimu',
#   'offices': [{'city': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
# ...
#     'longitude': -84.322687}]},
#  {'name': 'cScape',
#   'offices': [{'city': 'London',
#     'country_code': 'GBR',
#     'latitude': 51.523676,
#     'longitude': -0.107843}]},
#  {'name': 'Compulsivo',
#   'offices': [{'city': 'Austin',
#     'country_code': 'USA',
#     'latitude': 30.27646,
#     'longitude': -97.746387}]},
#  {'name': 'SurfControl',
#   'offices': [{'city': 'Scotts Valley',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Opinity',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Jose',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Los Angeles Times Media Group',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'EkoPLC',
#   'offices': [{'city': 'Palma de Mallorca',
#     'country_code': 'ESP',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Trackur',
#   'offices': [{'city': 'Raleigh',
#     'country_code': 'USA',
#     'latitude': 35.898459,
#     'longitude': -78.650931}]},
#  {'name': 'doubleTwist',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.775196,
#     'longitude': -122.419204}]},
#  {'name': 'EnergyWeb Solutions',
#   'offices': [{'city': 'Allentown',
#     'country_code': 'USA',
#     'latitude': 40.58471,
#     'longitude': -75.588974},
#    {'city': 'Allentown',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Online-Access',
#   'offices': [{'city': 'Port Huron',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'IShareWeShare',
#   'offices': [{'city': 'Givataym',
#     'country_code': 'ISR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Echobit',
#   'offices': [{'city': 'Minneapolis',
#     'country_code': 'USA',
#     'latitude': 44.977482,
#     'longitude': -93.264351}]},
#  {'name': 'Motionplan',
#   'offices': [{'city': 'Sewickley',
#     'country_code': 'USA',
#     'latitude': 40.61323,
#     'longitude': -80.101527}]},
#  {'name': 'Princeton Review',
#   'offices': [{'city': 'Framingham',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'sMoneyBox',
#   'offices': [{'city': '',
#     'country_code': 'CZE',
#     'latitude': 49.817492,
#     'longitude': 15.472962}]},
#  {'name': 'Pollsit',
#   'offices': [{'city': 'Lincoln',
#     'country_code': 'USA',
#     'latitude': 40.748578,
#     'longitude': -96.666242}]},
#  {'name': 'Tipped',
#   'offices': [{'city': 'London',
#     'country_code': 'GBR',
#     'latitude': 51.5211159,
#     'longitude': -0.0778345}]},
#  {'name': 'Tacit Software',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.451013,
#     'longitude': -122.120699}]},
#  {'name': 'Newspond',
#   'offices': [{'city': 'Edmonton, Alberta',
#     'country_code': 'CAN',
#     'latitude': 53.4665377,
#     'longitude': -113.5291728}]},
#  {'name': 'YouCastr',
#   'offices': [{'city': 'Cambridge',
#     'country_code': 'USA',
#     'latitude': 42.36787,
#     'longitude': -71.078258}]},
#  {'name': 'Hotwire',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.795236,
#     'longitude': -122.403607}]},
#  {'name': 'JackPot Rewards',
#   'offices': [{'city': 'Newton',
#     'country_code': 'USA',
#     'latitude': 42.337037,
#     'longitude': -71.251748}]},
#  {'name': 'Newsclipper',
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': 37.269175,
#     'longitude': -119.306607}]},
#  {'name': 'Paprika Lab',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Seoul',
#     'country_code': 'KOR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Agematis',
#   'offices': [{'city': 'Paris',
#     'country_code': 'FRA',
#     'latitude': 48.882647,
#     'longitude': 2.322551}]},
#  {'name': 'RiffTrax',
#   'offices': [{'city': 'San Diego',
#     'country_code': 'USA',
#     'latitude': 32.936973,
#     'longitude': -117.240431}]},
#  {'name': 'World Reviewer',
#   'offices': [{'city': 'London',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'FameCast',
#   'offices': [{'city': 'Austin',
#     'country_code': 'USA',
#     'latitude': 30.268735,
#     'longitude': -97.745209}]},
#  {'name': 'Grooveshark',
#   'offices': [{'city': 'Gainesville',
#     'country_code': 'USA',
#     'latitude': 29.6502461,
#     'longitude': -82.3230981}]},
#  {'name': 'MyApartmentMap', 'offices': []},
#  {'name': 'HD Greetings',
#   'offices': [{'city': 'Burlingame',
#     'country_code': 'USA',
#     'latitude': 37.590056,
#     'longitude': -122.347654}]},
#  {'name': 'Redux',
#   'offices': [{'city': 'Berkeley',
#     'country_code': 'USA',
#     'latitude': 37.87168,
#     'longitude': -122.269494}]},
#  {'name': '8coupons',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.7431477,
#     'longitude': -73.9934288}]},
#  {'name': 'CineGoGo',
#   'offices': [{'city': 'San Mateo',
#     'country_code': 'USA',
#     'latitude': 37.534317,
#     'longitude': -122.294847}]},
#  {'name': 'Evernote',
#   'offices': [{'city': 'Redwood City',
#     'country_code': 'USA',
#     'latitude': 37.386774,
#     'longitude': -121.987661}]},
#  {'name': 'Newsfutures', 'offices': []},
#  {'name': 'Music Nation', 'offices': []},
#  {'name': 'ePillager',
#   'offices': [{'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': 34.029209,
#     'longitude': -118.289344}]},
#  {'name': 'Cloudo',
#   'offices': [{'city': 'Stockholm',
#     'country_code': 'SWE',
#     'latitude': 59.336527,
#     'longitude': 18.077451}]},
#  {'name': 'Raptr',
#   'offices': [{'city': 'Mountain View',
#     'country_code': 'USA',
#     'latitude': 37.40384,
#     'longitude': -122.07808}]},
#  {'name': 'Intuit',
#   'offices': [{'city': 'Mountain View',
#     'country_code': 'USA',
#     'latitude': 37.428373,
#     'longitude': -122.097604},
#    {'city': 'San Diego',
#     'country_code': 'USA',
#     'latitude': 32.957695,
#     'longitude': -117.158245}]},
#  {'name': 'JuicyCampus',
#   'offices': [{'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': 33.954874,
#     'longitude': -118.396507}]},
#  {'name': 'Franz',
#   'offices': [{'city': 'Oakland',
#     'country_code': 'USA',
#     'latitude': 37.810949,
#     'longitude': -122.26706}]},
#  {'name': 'Swarmcast',
#   'offices': [{'city': 'Minneapolis',
#     'country_code': 'USA',
#     'latitude': 44.977482,
#     'longitude': -93.264351}]},
#  {'name': 'Inform Technologies',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.744639,
#     'longitude': -73.983963}]},
#  {'name': 'iOpener',
#   'offices': [{'city': 'Aachen',
#     'country_code': 'DEU',
#     'latitude': 50.791481,
#     'longitude': 6.066681}]},
#  {'name': 'Camlink',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Los Gatos',
#     'country_code': 'USA',
#     'latitude': 40.757929,
#     'longitude': -73.985506}]},
#  {'name': 'Ephox',
#   'offices': [{'city': 'Sacramento',
#     'country_code': 'USA',
#     'latitude': 37.444188,
#     'longitude': -122.163745},
#    {'city': 'Paddington',
#     'country_code': 'AUS',
#     'latitude': -27.460736,
#     'longitude': 153.004254},
#    {'city': 'Maidenhead',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Inuk Networks',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'Abercynon',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Sxoop Technologies',
#   'offices': [{'city': 'Cork',
#     'country_code': 'IRL',
#     'latitude': 51.8892282,
#     'longitude': -8.5240303}]},
#  {'name': 'Kluster',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.723652,
#     'longitude': -73.985281}]},
#  {'name': 'TripSailor',
#   'offices': [{'city': 'Las Vegas',
#     'country_code': 'USA',
#     'latitude': 36.225757,
#     'longitude': -115.217851}]},
#  {'name': 'Blog Talk Radio',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.757929,
#     'longitude': -73.985506}]},
#  {'name': 'HealtheHuman',
#   'offices': [{'city': 'Del Mar',
#     'country_code': 'USA',
#     'latitude': 34.423403,
#     'longitude': -119.704416}]},
#  {'name': 'Operation Sports',
#   'offices': [{'city': 'Woodbridge',
#     'country_code': 'USA',
#     'latitude': 38.6581,
#     'longitude': -77.2501}]},
#  {'name': 'Realtime Applications',
#   'offices': [{'city': 'Birmingham',
#     'country_code': 'USA',
#     'latitude': 33.477448,
#     'longitude': -86.819367}]},
#  {'name': 'Opera Software',
#   'offices': [{'city': 'Oslo',
#     'country_code': 'NOR',
#     'latitude': 59.928267,
#     'longitude': 10.754932},
#    {'city': 'Oslo',
#     'country_code': 'DEU',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Linköping',
#     'country_code': 'SWE',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Göteborg',
#     'country_code': 'SWE',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Mountain View',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'San Diego',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Tokyo',
#     'country_code': 'JPN',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Beijing',
#     'country_code': 'CHN',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Seoul',
#     'country_code': 'KOR',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Chandigarh',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Warsaw',
#     'country_code': 'POL',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Wrocław',
#     'country_code': 'POL',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Taipei',
#     'country_code': 'TWN',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Stratfor',
#   'offices': [{'city': 'Austin',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Top of the Barrel',
#   'offices': [{'city': 'Austin',
#     'country_code': 'USA',
#     'latitude': 30.414146,
#     'longitude': -97.807032}]},
#  {'name': 'Zorpia',
#   'offices': [{'city': 'Causeway Bay',
#     'country_code': 'HKG',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'MT Mind Technology',
#   'offices': [{'city': 'Victoria, BC',
#     'country_code': 'CAN',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'ooVoo',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Issuu',
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.4784804,
#     'longitude': -122.1514101}]},
#  {'name': 'Scred',
#   'offices': [{'city': 'Kauniainen',
#     'country_code': 'FIN',
#     'latitude': 60.214102,
#     'longitude': 24.704663}]},
#  {'name': 'Popularo',
#   'offices': [{'city': 'Philadelphia',
#     'country_code': 'USA',
#     'latitude': 39.951639,
#     'longitude': -75.163808}]},
#  {'name': 'The Fish Pool',
#   'offices': [{'city': 'Helsinki',
#     'country_code': 'FIN',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Animax Entertainment',
#   'offices': [{'city': 'Van Nuys',
#     'country_code': 'USA',
#     'latitude': 34.19099,
#     'longitude': -118.486428}]},
#  {'name': '2threads',
#   'offices': [{'city': 'sydney',
#     'country_code': 'AUS',
#     'latitude': -33.884685,
#     'longitude': 151.216427}]},
#  {'name': 'Blogged',
#   'offices': [{'city': 'Alhambra',
#     'country_code': 'USA',
#     'latitude': 34.091562,
#     'longitude': -118.13461}]},
#  {'name': 'SugarSync',
#   'offices': [{'city': 'San Mateo',
#     'country_code': 'USA',
#     'latitude': 37.54763,
#     'longitude': -122.307887}]},
#  {'name': 'Manvite',
#   'offices': [{'city': 'San Diego',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'ePals',
#   'offices': [{'city': 'Herndon',
#     'country_code': 'USA',
#     'latitude': 38.95424,
#     'longitude': -77.416331}]},
#  {'name': 'National Geographic',
#   'offices': [{'city': 'Washington',
#     'country_code': 'USA',
#     'latitude': 38.904592,
#     'longitude': -77.038503}]},
#  {'name': 'Phorm',
#   'offices': [{'city': 'London',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'BillShrink',
#   'offices': [{'city': 'Redwood City',
#     'country_code': 'USA',
#     'latitude': 37.503147,
#     'longitude': -122.211435}]},
#  {'name': 'Reble',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.775196,
#     'longitude': -122.419204}]},
#  {'name': 'Skobee',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'EMOB',
#   'offices': [{'city': 'Toulon',
#     'country_code': 'FRA',
#     'latitude': 43.124351,
#     'longitude': 5.929313}]},
#  {'name': 'Outbrain',
#   'offices': [{'city': 'New York City',
#     'country_code': 'USA',
#     'latitude': 40.757929,
#     'longitude': -73.985506},
#    {'city': 'Netanya',
#     'country_code': 'ISR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'The Industry Standard',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.783151,
#     'longitude': -122.393323}]},
#  {'name': 'DivX',
#   'acquisition': {'price_amount': 323000000},
#   'offices': [{'city': 'San Diego',
#     'country_code': 'USA',
#     'latitude': 32.880882,
#     'longitude': -117.203309}]},
#  {'name': 'iambic',
#   'offices': [{'city': 'Sunnyvale',
#     'country_code': 'USA',
#     'latitude': 37.386376,
#     'longitude': -121.991471}]},
#  {'name': 'PhotoCrank',
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.445326,
#     'longitude': -122.160671}]},
#  {'name': 'Trilogy',
#   'offices': [{'city': 'Austin',
#     'country_code': 'USA',
#     'latitude': 30.26652,
#     'longitude': -97.7429367}]},
#  {'name': 'Gamers Media',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.757929,
#     'longitude': -73.985506}]},
#  {'name': 'NAVIS',
#   'offices': [{'city': 'Bend',
#     'country_code': 'USA',
#     'latitude': 44.059936,
#     'longitude': -121.307839}]},
#  {'name': 'Mowser', 'acquisition': {'price_amount': None}, 'offices': []},
#  {'name': 'Answerology',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.735537,
#     'longitude': -74.006179}]},
#  {'name': 'AnswerBag', 'offices': []},
#  {'name': 'Zilpy',
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': 37.419156,
#     'longitude': -122.075413}]},
#  {'name': 'OLX',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.8587524,
#     'longitude': -73.7258199}]},
#  {'name': 'Tinypic',
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': 32.6460331,
#     'longitude': -16.9147342}]},
#  {'name': 'Clusty',
#   'acquisition': {'price_amount': 5600000},
#   'offices': [{'city': 'Pittsburgh',
#     'country_code': 'USA',
#     'latitude': 40.431653,
#     'longitude': -79.915015}]},
#  {'name': 'BEA Systems',
#   'acquisition': {'price_amount': 8500000000},
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': 37.378943,
#     'longitude': -121.92401}]},
#  {'name': 'Fifteen Reasons',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 41.948365,
#     'longitude': -87.646307}]},
#  {'name': 'I Heart Movies',
#   'offices': [{'city': 'Midland',
#     'country_code': 'USA',
#     'latitude': 43.626128,
#     'longitude': -84.227415}]},
#  {'name': 'ulink',
#   'offices': [{'city': 'Fremont',
#     'country_code': 'USA',
#     'latitude': 37.548615,
#     'longitude': -121.988479}]},
#  {'name': 'Collactive',
#   'offices': [{'city': 'Wilmington',
#     'country_code': 'USA',
#     'latitude': 39.748985,
#     'longitude': -75.546329}]},
#  {'name': 'Panther Express',
#   'acquisition': {'price_amount': None},
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  ...]

# %%
city=[i['offices'] for i in filt_list]
city
# Out:
# [[{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 47.603122,
#    'longitude': -122.333253},
#   {'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.7237306,
#    'longitude': -73.9964312}],
#  [{'city': 'Pleasanton',
#    'country_code': 'USA',
#    'latitude': 37.692934,
#    'longitude': -121.904945}],
#  [{'city': 'San Carlos',
#    'country_code': 'USA',
#    'latitude': 37.506885,
#    'longitude': -122.247573}],
#  [{'city': 'West Hollywood',
#    'country_code': 'USA',
#    'latitude': 34.090368,
#    'longitude': -118.393064}],
#  [{'city': 'Culver City',
#    'country_code': 'USA',
#    'latitude': 34.025958,
#    'longitude': -118.379768}],
#  [{'city': 'Beverly Hills',
#    'country_code': 'USA',
#    'latitude': 34.076179,
#    'longitude': -118.39417}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.775196,
#    'longitude': -122.419204},
#   {'city': 'New York City',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Menlo Park',
#    'country_code': 'USA',
#    'latitude': 37.48413,
#    'longitude': -122.169472}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.451151,
#    'longitude': -122.154369}],
#  [{'city': 'San Jose',
#    'country_code': 'USA',
#    'latitude': 37.295005,
#    'longitude': -121.930035}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.7464969,
#    'longitude': -74.0094471}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.757725,
#    'longitude': -73.986011}],
#  [{'city': 'London',
#    'country_code': 'GBR',
#    'latitude': 53.344104,
#    'longitude': -6.267494}],
#  [{'city': 'Sunnyvale',
#    'country_code': 'USA',
#    'latitude': 37.387845,
#    'longitude': -122.055197}],
#  [{'city': 'Sunnyvale',
#    'country_code': 'USA',
#    'latitude': 37.418531,
#    'longitude': -122.025485}],
#  [{'city': 'Culver City',
#    'country_code': 'USA',
#    'latitude': 34.017606,
#    'longitude': -118.487267}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.788482,
#    'longitude': -122.409173}],
#  [{'city': 'San Diego',
#    'country_code': 'USA',
#    'latitude': 32.902266,
#    'longitude': -117.20834}],
#  [{'city': 'McLean',
#    'country_code': 'USA',
#    'latitude': 38.929289,
#    'longitude': -77.216585}],
#  [{'city': 'Austin',
#    'country_code': 'USA',
#    'latitude': 30.268735,
#    'longitude': -97.745209}],
#  [{'city': 'Chicago',
#    'country_code': 'USA',
#    'latitude': 41.885619,
#    'longitude': -87.622309}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.437328,
#    'longitude': -122.159928}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.72604,
#    'longitude': -73.995722}],
#  [{'city': 'Sunnyvale',
#    'country_code': 'USA',
#    'latitude': 37.384239,
#    'longitude': -122.012475}],
#  [{'city': '',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.793148,
#    'longitude': -122.402567}],
#  [{'city': 'Pleasanton',
#    'country_code': 'USA',
#    'latitude': 37.697805,
#    'longitude': -121.907768}],
#  [{'city': 'Luxembourg City',
#    'country_code': 'LUX',
#    'latitude': 51.518132,
#    'longitude': -0.131916},
#   {'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'London',
#    'country_code': 'GBR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Bruno',
#    'country_code': 'USA',
#    'latitude': 37.627971,
#    'longitude': -122.426804}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 34.051409,
#    'longitude': -118.254558}],
#  [{'city': 'Ramat Gan',
#    'country_code': 'ISR',
#    'latitude': 31.046051,
#    'longitude': 34.851612}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.726155,
#    'longitude': -73.995625}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.392936,
#    'longitude': -122.07948},
#   {'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Budapest',
#    'country_code': 'HUN',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'NYC',
#    'country_code': 'USA',
#    'latitude': 40.801358,
#    'longitude': -74.3372}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.722655,
#    'longitude': -73.99873}],
#  [{'city': 'Stamford',
#    'country_code': 'USA',
#    'latitude': 41.049051,
#    'longitude': -73.563878}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.44296,
#    'longitude': -122.151198}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.762541,
#    'longitude': -122.397224}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.757758,
#    'longitude': -122.388243}],
#  [{'city': 'Oxford',
#    'country_code': 'GBR',
#    'latitude': 51.752276,
#    'longitude': -1.255824}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.269175,
#    'longitude': -119.306607}],
#  [{'city': 'Encino',
#    'country_code': 'USA',
#    'latitude': 37.269175,
#    'longitude': -119.306607}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.780716,
#    'longitude': -122.393913}],
#  [{'city': 'Moscow',
#    'country_code': 'RUS',
#    'latitude': 55.755786,
#    'longitude': 37.617633}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.553385,
#    'longitude': -122.302149}],
#  [{'city': '46395 Bocholt',
#    'country_code': 'DEU',
#    'latitude': 51.808933,
#    'longitude': 6.553452}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.421621,
#    'longitude': -122.137444}],
#  [{'city': 'Dublin',
#    'country_code': 'IRL',
#    'latitude': 53.354997,
#    'longitude': -6.229255}],
#  [{'city': 'Burlingame',
#    'country_code': 'USA',
#    'latitude': 37.590339,
#    'longitude': -122.341715}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.793819,
#    'longitude': -122.395089}],
#  [{'city': 'Agoura Hills',
#    'country_code': 'USA',
#    'latitude': 34.155211,
#    'longitude': -118.756618}],
#  [{'city': 'Toronto, Ontario',
#    'country_code': 'CAN',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Santa Clara',
#    'country_code': 'USA',
#    'latitude': 37.380101,
#    'longitude': -121.940749}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 34.052187,
#    'longitude': -118.243425}],
#  [{'city': 'Amsterdam',
#    'country_code': 'NLD',
#    'latitude': 52.3745228,
#    'longitude': 4.8948623}],
#  [{'city': 'Amsterdam',
#    'country_code': 'NLD',
#    'latitude': 52.375595,
#    'longitude': 4.908556}],
#  [{'city': 'Redwood City',
#    'country_code': 'USA',
#    'latitude': 37.476479,
#    'longitude': -122.221717}],
#  [{'city': 'Southampton',
#    'country_code': 'GBR',
#    'latitude': 50.9444598,
#    'longitude': -1.3610845}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.775196,
#    'longitude': -122.419204}],
#  [{'city': 'Santa Clara',
#    'country_code': 'USA',
#    'latitude': 37.374998,
#    'longitude': -121.977853}],
#  [{'city': 'Sunnyvale',
#    'country_code': 'USA',
#    'latitude': 37.36965,
#    'longitude': -122.02421}],
#  [{'city': 'Redwood City',
#    'country_code': 'USA',
#    'latitude': 37.484619,
#    'longitude': -122.206893}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.758113,
#    'longitude': -122.414689}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.7791761,
#    'longitude': -122.4058887}],
#  [{'city': 'Paris',
#    'country_code': 'FRA',
#    'latitude': 48.870806,
#    'longitude': 2.34668},
#   {'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.781427,
#    'longitude': -122.392144}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.782103,
#    'longitude': -122.401116}],
#  [{'city': 'Sunnyvale',
#    'country_code': 'USA',
#    'latitude': 37.418531,
#    'longitude': -122.025485}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.778076,
#    'longitude': -122.397977}],
#  [{'city': '',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 47.614653,
#    'longitude': -122.338793}],
#  [{'city': 'Mill Valley',
#    'country_code': 'USA',
#    'latitude': 37.90077,
#    'longitude': -122.511687}],
#  [{'city': 'Chicago',
#    'country_code': 'USA',
#    'latitude': 41.889474,
#    'longitude': -87.628912}],
#  [{'city': 'Paris',
#    'country_code': 'FRA',
#    'latitude': 48.856667,
#    'longitude': 2.350987}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.762681,
#    'longitude': -122.400909}],
#  [{'city': 'Paris',
#    'country_code': 'FRA',
#    'latitude': 48.866323,
#    'longitude': 2.381514}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.796396,
#    'longitude': -122.404869}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': 37.393679,
#    'longitude': -122.079017},
#   {'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Santa Monica',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'New York',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Chicago',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.779507,
#    'longitude': -122.39071}],
#  [{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 47.618599,
#    'longitude': -122.358484}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.437328,
#    'longitude': -122.159928}],
#  [{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 47.615313,
#    'longitude': -122.323408}],
#  [{'city': 'West Hollywood',
#    'country_code': 'USA',
#    'latitude': 34.0906602,
#    'longitude': -118.3835957}],
#  [{'city': 'San Diego',
#    'country_code': 'USA',
#    'latitude': 32.718834,
#    'longitude': -117.163841}],
#  [{'city': 'Tel Aviv',
#    'country_code': 'ISR',
#    'latitude': 32.0554,
#    'longitude': 34.7595}],
#  [{'city': 'Geneva',
#    'country_code': 'CHE',
#    'latitude': 46.20381,
#    'longitude': 6.139959}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.775196,
#    'longitude': -122.419204}],
#  [{'city': 'Cincinnati',
#    'country_code': 'USA',
#    'latitude': 39.06685,
#    'longitude': -84.351532}],
#  [{'city': 'Charlottesville',
#    'country_code': 'USA',
#    'latitude': 38.030823,
#    'longitude': -78.48158}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.553121,
#    'longitude': -122.301534}],
#  [{'city': 'Burlingame',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.7618242,
#    'longitude': -122.3985871}],
#  [{'city': 'San Diego',
#    'country_code': 'USA',
#    'latitude': 32.872081,
#    'longitude': -117.206292},
#   {'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Diego',
#    'country_code': 'USA',
#    'latitude': 39.9195028,
#    'longitude': -105.1110024}],
#  [{'city': 'Redwood City',
#    'country_code': 'USA',
#    'latitude': 37.479952,
#    'longitude': -122.178557}],
#  [{'city': 'Knoxville',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.76785,
#    'longitude': -122.392861}],
#  [{'city': 'Vashon',
#    'country_code': 'USA',
#    'latitude': 47.420728,
#    'longitude': -122.450942}],
#  [{'city': 'Woodland Hills',
#    'country_code': 'USA',
#    'latitude': 34.184598,
#    'longitude': -118.601532}],
#  [{'city': '',
#    'country_code': 'USA',
#    'latitude': 34.070436,
#    'longitude': -118.350486}],
#  [{'city': 'Los Gatos',
#    'country_code': 'USA',
#    'latitude': 37.255118,
#    'longitude': -121.96533}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.782263,
#    'longitude': -122.392142}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.766909,
#    'longitude': -122.406676}],
#  [{'city': 'Arlington',
#    'country_code': 'USA',
#    'latitude': 38.897428,
#    'longitude': -77.072003}],
#  [{'city': 'Mill Valley',
#    'country_code': 'USA',
#    'latitude': 37.905544,
#    'longitude': -122.547445}],
#  [{'city': 'Seoul',
#    'country_code': 'KOR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': 37.40047,
#    'longitude': -122.072981}],
#  [{'city': 'Austin',
#    'country_code': 'USA',
#    'latitude': 30.407545,
#    'longitude': -97.717667}],
#  [{'city': 'Pleasanton',
#    'country_code': 'USA',
#    'latitude': 37.6637279,
#    'longitude': -121.8731805},
#   {'city': 'Reston',
#    'country_code': 'USA',
#    'latitude': 38.9590083,
#    'longitude': -77.3592746},
#   {'city': 'London',
#    'country_code': 'GBR',
#    'latitude': 51.5170385,
#    'longitude': -0.1394759}],
#  [{'city': 'London W11 2HX',
#    'country_code': 'GBR',
#    'latitude': 51.514935,
#    'longitude': -0.205349}],
#  [{'city': 'San Jose',
#    'country_code': 'USA',
#    'latitude': 37.321798,
#    'longitude': -121.979453},
#   {'city': 'London',
#    'country_code': 'GBR',
#    'latitude': 51.500152,
#    'longitude': -0.126236}],
#  [{'city': 'Bellevue',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.788668,
#    'longitude': -122.400558}],
#  [{'city': 'Bagnacavallo',
#    'country_code': 'ITA',
#    'latitude': 44.418166,
#    'longitude': 11.978686}],
#  [{'city': None,
#    'country_code': 'JPN',
#    'latitude': 36.204824,
#    'longitude': 138.252924}],
#  [{'city': 'Stamford',
#    'country_code': 'USA',
#    'latitude': 41.038155,
#    'longitude': -73.558082},
#   {'city': 'Austin',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.774321,
#    'longitude': -122.415375}],
#  [{'city': 'Montecito',
#    'country_code': 'USA',
#    'latitude': 34.42071,
#    'longitude': -119.641821}],
#  [{'city': 'Brighton',
#    'country_code': 'GBR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Boston',
#    'country_code': 'USA',
#    'latitude': 42.355672,
#    'longitude': -71.060864}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.55909,
#    'longitude': -122.321836}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.787092,
#    'longitude': -122.399972},
#   {'city': 'Huntsville',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.536172,
#    'longitude': -122.327323}],
#  [{'city': 'Mill Valley',
#    'country_code': 'USA',
#    'latitude': 37.898575,
#    'longitude': -122.537302}],
#  [{'city': 'Amsterdam',
#    'country_code': 'NLD',
#    'latitude': 52.3640933,
#    'longitude': 4.8919457},
#   {'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.787683,
#    'longitude': -122.410943},
#   {'city': 'Singapore',
#    'country_code': 'SGP',
#    'latitude': 51.500152,
#    'longitude': -0.126236}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': 37.419819,
#    'longitude': -122.090188}],
#  [{'city': 'San Jose',
#    'country_code': 'USA',
#    'latitude': 37.320052,
#    'longitude': -121.877636}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.779392,
#    'longitude': -122.417928}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.4858654,
#    'longitude': -122.2262606}],
#  [{'city': 'Phoenix',
#    'country_code': 'USA',
#    'latitude': 33.429864,
#    'longitude': -111.944967}],
#  [{'city': 'Sunnyvale',
#    'country_code': 'USA',
#    'latitude': 37.386376,
#    'longitude': -121.991471}],
#  [{'city': 'Sunnyvale',
#    'country_code': 'USA',
#    'latitude': 37.384651,
#    'longitude': -121.992132}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.446687,
#    'longitude': -122.163189}],
#  [{'city': '',
#    'country_code': 'USA',
#    'latitude': 37.269175,
#    'longitude': -119.306607}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.408256,
#    'longitude': -122.154176}],
#  [{'city': 'Vancouver',
#    'country_code': 'CAN',
#    'latitude': 49.283376,
#    'longitude': -123.103986}],
#  [{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 47.5999337,
#    'longitude': -122.3276962}],
#  [{'city': 'Culver City',
#    'country_code': 'USA',
#    'latitude': 34.017506,
#    'longitude': -118.401579}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.736416,
#    'longitude': -73.993302}],
#  [{'city': 'Sydney',
#    'country_code': 'AUS',
#    'latitude': -33.722577,
#    'longitude': 150.981801}],
#  [{'city': 'Boulder',
#    'country_code': 'USA',
#    'latitude': 40.010492,
#    'longitude': -105.276843}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.780883,
#    'longitude': -122.395257}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 47.61968,
#    'longitude': -122.356756}],
#  [{'city': 'Sunnyvale',
#    'country_code': 'USA',
#    'latitude': 37.368594,
#    'longitude': -122.034021}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': 37.400465,
#    'longitude': -122.073003}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': 37.386665,
#    'longitude': -122.084171}],
#  [{'city': 'Redmond',
#    'country_code': 'USA',
#    'latitude': 47.672229,
#    'longitude': -122.115633}],
#  [{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 47.620716,
#    'longitude': -122.347533}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.553743,
#    'longitude': -122.300246}],
#  [{'city': 'Tel Aviv',
#    'country_code': 'ISR',
#    'latitude': 32.0554,
#    'longitude': 34.7595}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Burbank',
#    'country_code': 'USA',
#    'latitude': 34.156802,
#    'longitude': -118.324987}],
#  [{'city': 'Singapore',
#    'country_code': 'SGP',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Waltham',
#    'country_code': 'USA',
#    'latitude': 42.417268,
#    'longitude': -71.258466}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 34.052187,
#    'longitude': -118.243425}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'West Hollywood',
#    'country_code': 'USA',
#    'latitude': 34.090932,
#    'longitude': -118.38428}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.7311317,
#    'longitude': -73.9919311}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.437328,
#    'longitude': -122.159928},
#   {'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'El Segundo',
#    'country_code': 'USA',
#    'latitude': 33.920296,
#    'longitude': -118.391852}],
#  [{'city': 'Atlanta',
#    'country_code': 'USA',
#    'latitude': 33.916374,
#    'longitude': -84.350663}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': 37.3927975,
#    'longitude': -122.0727749}],
#  [{'city': 'Boulder',
#    'country_code': 'USA',
#    'latitude': 40.010492,
#    'longitude': -105.276843}],
#  [{'city': None,
#    'country_code': 'ISR',
#    'latitude': 31.046051,
#    'longitude': 34.851612}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.437328,
#    'longitude': -122.159928}],
#  [{'city': 'Woodbridge',
#    'country_code': 'CAN',
#    'latitude': 43.76969,
#    'longitude': -79.549577}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Antonio',
#    'country_code': 'USA',
#    'latitude': 29.427051,
#    'longitude': -98.487764}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Newburyport',
#    'country_code': 'USA',
#    'latitude': 42.7973978,
#    'longitude': -70.8873327},
#   {'city': 'Las Vegas',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Helsinki',
#    'country_code': 'FIN',
#    'latitude': 60.165166,
#    'longitude': 24.945937}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Leeds',
#    'country_code': 'GBR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': '',
#    'country_code': 'ISR',
#    'latitude': 31.046051,
#    'longitude': 34.851612}],
#  [{'city': 'Venice',
#    'country_code': 'USA',
#    'latitude': 33.988337,
#    'longitude': -118.472721}],
#  [{'city': 'mem',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Naples',
#    'country_code': 'USA',
#    'latitude': 26.246414,
#    'longitude': -81.788104},
#   {'city': 'Atlanta',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Newport Beach',
#    'country_code': 'USA',
#    'latitude': 33.610083,
#    'longitude': -117.928351}],
#  [{'city': 'Arlington',
#    'country_code': 'USA',
#    'latitude': 38.892371,
#    'longitude': -77.081732}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 31.169036,
#    'longitude': -100.076888}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 34.052187,
#    'longitude': -118.243425}],
#  [{'city': 'Oceanside',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.437328,
#    'longitude': -122.159928}],
#  [{'city': 'Menlo Park',
#    'country_code': 'USA',
#    'latitude': 37.491356,
#    'longitude': -122.228843}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 34.101617,
#    'longitude': -118.327071}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.794649,
#    'longitude': -122.399646}],
#  [{'city': None,
#    'country_code': 'ISR',
#    'latitude': 17.08881,
#    'longitude': -96.76492}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.7909427,
#    'longitude': -122.4084994},
#   {'city': 'Dublin',
#    'country_code': 'IRL',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': '',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Menlo Park',
#    'country_code': 'USA',
#    'latitude': 37.48413,
#    'longitude': -122.169472}],
#  [{'city': '',
#    'country_code': 'ESP',
#    'latitude': 40.463667,
#    'longitude': -3.74922}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.780134,
#    'longitude': -122.396744}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.779507,
#    'longitude': -122.39071},
#   {'city': 'Ultimo',
#    'country_code': 'AUS',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'New York',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Barcelona, 08019',
#    'country_code': 'ESP',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Hamburg',
#    'country_code': 'DEU',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Tokyo',
#    'country_code': 'JPN',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Shanghai',
#    'country_code': 'CHN',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': '', 'country_code': 'USA', 'latitude': None, 'longitude': None}],
#  [{'city': 'Redmond',
#    'country_code': 'USA',
#    'latitude': 47.682233,
#    'longitude': -122.135521}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.795555,
#    'longitude': -122.400729}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.7911148,
#    'longitude': -122.3954751},
#   {'city': 'Cape Town',
#    'country_code': 'ZAF',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 38.805114,
#    'longitude': -77.236968}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.790998,
#    'longitude': -122.394668}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.786942,
#    'longitude': -122.401245}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.781557,
#    'longitude': -122.407959}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 40.010492,
#    'longitude': -105.276843}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.383779,
#    'longitude': -122.007172}],
#  [{'city': 'Pittsburgh',
#    'country_code': 'USA',
#    'latitude': 40.445009,
#    'longitude': -79.948563}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.752957,
#    'longitude': -73.98546}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Durham',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Minneapolis',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Melbourne',
#    'country_code': 'AUS',
#    'latitude': -37.814251,
#    'longitude': 144.963169}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 34.062262,
#    'longitude': -118.348198}],
#  [{'city': 'San Diego',
#    'country_code': 'USA',
#    'latitude': 32.71537,
#    'longitude': -117.163353}],
#  [{'city': 'Paris',
#    'country_code': 'FRA',
#    'latitude': 48.856667,
#    'longitude': 2.350987}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.444554,
#    'longitude': -122.164511}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.427235,
#    'longitude': -122.145783}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.705898,
#    'longitude': -74.011398}],
#  [{'city': 'Andover',
#    'country_code': 'USA',
#    'latitude': 42.675189,
#    'longitude': -71.1469}],
#  [{'city': 'Henderson',
#    'country_code': 'USA',
#    'latitude': 36.032976,
#    'longitude': -115.064859},
#   {'city': 'Shepherdsville',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Bellevue',
#    'country_code': 'USA',
#    'latitude': 47.579208,
#    'longitude': -122.155668}],
#  [{'city': 'Santa Monica',
#    'country_code': 'USA',
#    'latitude': 34.018275,
#    'longitude': -118.495025}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.782263,
#    'longitude': -122.392142}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 47.610332,
#    'longitude': -122.339859}],
#  [{'city': 'Austin',
#    'country_code': 'USA',
#    'latitude': 30.268735,
#    'longitude': -97.745209}],
#  [{'city': 'Menlo Park',
#    'country_code': 'USA',
#    'latitude': 37.48413,
#    'longitude': -122.169472}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': 37.40047,
#    'longitude': -122.072981}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Belmont',
#    'country_code': 'USA',
#    'latitude': 37.524422,
#    'longitude': -122.265869},
#   {'city': 'Santa Monica',
#    'country_code': 'USA',
#    'latitude': 34.017373,
#    'longitude': -118.453218},
#   {'city': 'Fort Lauderdale',
#    'country_code': 'USA',
#    'latitude': 26.207024,
#    'longitude': -80.157296}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.790964,
#    'longitude': -122.401128}],
#  [{'city': 'Marina Del Rey',
#    'country_code': 'USA',
#    'latitude': 33.983543,
#    'longitude': -118.432526}],
#  [{'city': 'Santa Monica',
#    'country_code': 'USA',
#    'latitude': 34.145946,
#    'longitude': -118.132351}],
#  [{'city': 'Kuala Lumpur',
#    'country_code': 'MYS',
#    'latitude': 3.139003,
#    'longitude': 101.686855}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.753385,
#    'longitude': -73.98962}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.731118,
#    'longitude': -73.991933}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.731118,
#    'longitude': -73.991933}],
#  [{'city': 'Bath, Somerset',
#    'country_code': 'GBR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Germantown',
#    'country_code': 'USA',
#    'latitude': 39.2009241,
#    'longitude': -77.2630048}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.746953,
#    'longitude': -73.993553}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 33.979033,
#    'longitude': -118.423423},
#   {'city': 'Marina Del Rey',
#    'country_code': 'USA',
#    'latitude': 33.979506,
#    'longitude': -118.439787}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.554595,
#    'longitude': -122.317471}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891},
#   {'city': 'London',
#    'country_code': 'GBR',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'New York',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Chicago',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 55.378051,
#    'longitude': -3.435973}],
#  [{'city': 'Southlake',
#    'country_code': 'USA',
#    'latitude': 32.9819881,
#    'longitude': -97.1599393}],
#  [{'city': 'London',
#    'country_code': 'GBR',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Glendale',
#    'country_code': 'USA',
#    'latitude': 34.155224,
#    'longitude': -118.255197}],
#  [{'city': 'Andover',
#    'country_code': 'USA',
#    'latitude': 42.656621,
#    'longitude': -71.140538}],
#  [{'city': 'Fort Lauderdale',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Boston',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891},
#   {'city': 'Neuilly sur Seine',
#    'country_code': 'FRA',
#    'latitude': 48.882314,
#    'longitude': 2.2673953}],
#  [{'city': 'Corte Madera',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.785647,
#    'longitude': -122.405265}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Boston',
#    'country_code': 'USA',
#    'latitude': 42.350274,
#    'longitude': -71.058768}],
#  [{'city': 'Bellevue',
#    'country_code': 'USA',
#    'latitude': 47.597965,
#    'longitude': -122.151158}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Saint Louis',
#    'country_code': 'USA',
#    'latitude': 38.618874,
#    'longitude': -90.216499}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Bangalore',
#    'country_code': 'IND',
#    'latitude': 12.971606,
#    'longitude': 77.594376}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Arlington',
#    'country_code': 'USA',
#    'latitude': 42.417903,
#    'longitude': -71.164975}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.757929,
#    'longitude': -73.985506}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Waltham',
#    'country_code': 'USA',
#    'latitude': 42.393662,
#    'longitude': -71.255855}],
#  [{'city': 'Santa Monica',
#    'country_code': 'USA',
#    'latitude': 34.0184659,
#    'longitude': -118.49863}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'New  York',
#    'country_code': 'USA',
#    'latitude': 40.757929,
#    'longitude': -73.985506}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.553743,
#    'longitude': -122.300246}],
#  [{'city': 'London',
#    'country_code': 'GBR',
#    'latitude': 51.5192042,
#    'longitude': -0.1626103}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'London',
#    'country_code': 'GBR',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.433414,
#    'longitude': -122.128772}],
#  [{'city': 'Norcross',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.707921,
#    'longitude': -74.004792}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.775196,
#    'longitude': -122.419204}],
#  [{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 47.5999337,
#    'longitude': -122.3276962}],
#  [{'city': 'San Diego',
#    'country_code': 'USA',
#    'latitude': 32.901317,
#    'longitude': -117.200492}],
#  [{'city': 'Toronto',
#    'country_code': 'CAN',
#    'latitude': 43.799511,
#    'longitude': -79.348037}],
#  [{'city': 'San Jose',
#    'country_code': 'USA',
#    'latitude': 37.316466,
#    'longitude': -121.873881}],
#  [{'city': 'Newton',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Cerritos',
#    'country_code': 'AFG',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.723384,
#    'longitude': -74.001704},
#   {'city': 'Austin',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Sassenage',
#    'country_code': 'FRA',
#    'latitude': 45.206889,
#    'longitude': 5.659066}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.781265,
#    'longitude': -122.393229}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Brussel',
#    'country_code': 'BEL',
#    'latitude': 50.796645,
#    'longitude': 4.400604}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.74406,
#    'longitude': -74.004592}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Eden Prairie',
#    'country_code': 'USA',
#    'latitude': 44.865243,
#    'longitude': -93.4094629}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.447969,
#    'longitude': -122.119417}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 34.031276,
#    'longitude': -118.456806}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': 37.40047,
#    'longitude': -122.072981}],
#  [{'city': '', 'country_code': 'USA', 'latitude': None, 'longitude': None}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.453687,
#    'longitude': -122.228595}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.753202,
#    'longitude': -73.986771}],
#  [{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 47.611012,
#    'longitude': -122.333523}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Cambridge',
#    'country_code': 'GBR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.723703,
#    'longitude': -73.99644}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Frankfurt am Main',
#    'country_code': 'DEU',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Boulder',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Portland',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Or Yehuda',
#    'country_code': 'ISR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Austin',
#    'country_code': 'USA',
#    'latitude': 30.34497,
#    'longitude': -97.770174}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'McLean',
#    'country_code': 'USA',
#    'latitude': 38.003376,
#    'longitude': -79.420926}],
#  [{'city': 'Boulder',
#    'country_code': 'USA',
#    'latitude': 40.048078,
#    'longitude': -105.38018}],
#  [{'city': 'New London',
#    'country_code': 'USA',
#    'latitude': 41.345754,
#    'longitude': -72.105722}],
#  [{'city': 'Chicago',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'La Jolla',
#    'country_code': 'USA',
#    'latitude': 32.847521,
#    'longitude': -117.274609}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 34.0481711,
#    'longitude': -118.4419012}],
#  [{'city': 'METZ',
#    'country_code': 'FRA',
#    'latitude': 49.1004,
#    'longitude': 6.182658}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.793742,
#    'longitude': -122.421341}],
#  [{'city': 'Toronto',
#    'country_code': 'CAN',
#    'latitude': 43.6501051,
#    'longitude': -79.396805}],
#  [{'city': 'Portland',
#    'country_code': 'USA',
#    'latitude': 45.5241278,
#    'longitude': -122.675448}],
#  [{'city': 'Rockville',
#    'country_code': 'USA',
#    'latitude': 39.052614,
#    'longitude': -77.123153}],
#  [{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 47.6015315,
#    'longitude': -122.335943}],
#  [{'city': '',
#    'country_code': 'CAN',
#    'latitude': 56.130366,
#    'longitude': -106.346771}],
#  [{'city': 'Berlin',
#    'country_code': 'DEU',
#    'latitude': 52.5013449,
#    'longitude': 13.4109071},
#   {'city': 'Hannover',
#    'country_code': 'DEU',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'The Woodlands',
#    'country_code': 'USA',
#    'latitude': 30.182107,
#    'longitude': -95.536}],
#  [{'city': 'Santa Monica',
#    'country_code': 'USA',
#    'latitude': 34.01052,
#    'longitude': -118.495981}],
#  [{'city': 'Sammamish',
#    'country_code': 'USA',
#    'latitude': 47.585114,
#    'longitude': -122.084356}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 33.959799,
#    'longitude': -118.343938}],
#  [{'city': 'Paris',
#    'country_code': 'FRA',
#    'latitude': 48.8558532,
#    'longitude': 2.3365754}],
#  [{'city': 'Chicago',
#    'country_code': 'USA',
#    'latitude': 41.890376,
#    'longitude': -87.63406}],
#  [{'city': 'Needham',
#    'country_code': 'USA',
#    'latitude': 42.296111,
#    'longitude': -71.238524}],
#  [{'city': 'Boulder',
#    'country_code': 'USA',
#    'latitude': 40.010492,
#    'longitude': -105.276843}],
#  [{'city': 'Redmond',
#    'country_code': 'USA',
#    'latitude': 47.672229,
#    'longitude': -122.115633}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.786175,
#    'longitude': -122.389676}],
#  [{'city': 'West Palm Beach',
#    'country_code': 'USA',
#    'latitude': 43.67084,
#    'longitude': -83.913153}],
#  [{'city': 'Sunnyvale',
#    'country_code': 'USA',
#    'latitude': 37.368594,
#    'longitude': -122.034021}],
#  [{'city': 'Cambridge',
#    'country_code': 'USA',
#    'latitude': 42.375392,
#    'longitude': -71.118487}],
#  [{'city': 'London',
#    'country_code': 'GBR',
#    'latitude': 51.523789,
#    'longitude': -0.087432}],
#  [{'city': 'Tokyo',
#    'country_code': 'JPN',
#    'latitude': 35.6158956,
#    'longitude': 139.7492374},
#   {'city': '', 'country_code': 'GBR', 'latitude': None, 'longitude': None},
#   {'city': '', 'country_code': 'JOR', 'latitude': None, 'longitude': None}],
#  [{'city': 'Tokyo',
#    'country_code': 'JPN',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Westlake Village',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'London',
#    'country_code': 'GBR',
#    'latitude': 51.519819,
#    'longitude': -0.136174}],
#  [{'city': 'Singapore',
#    'country_code': 'SGP',
#    'latitude': 37.580304,
#    'longitude': -122.343679}],
#  [{'city': 'Cambridge',
#    'country_code': 'USA',
#    'latitude': 42.375392,
#    'longitude': -71.118487}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 36.076705,
#    'longitude': -115.089514}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.557637,
#    'longitude': -122.285714}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.799549,
#    'longitude': -122.306571}],
#  [{'city': 'Los Gatos',
#    'country_code': 'USA',
#    'latitude': 37.222604,
#    'longitude': -121.983814}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 33.945553,
#    'longitude': -118.441219}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 34.064491,
#    'longitude': -118.42749}],
#  [{'city': 'Berkeley',
#    'country_code': 'USA',
#    'latitude': 37.887864,
#    'longitude': -122.26999}],
#  [{'city': 'Solana Beach',
#    'country_code': 'USA',
#    'latitude': 33.020832,
#    'longitude': -117.077311}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.789634,
#    'longitude': -122.404052}],
#  [{'city': 'Salt Lake City',
#    'country_code': 'AFG',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.559287,
#    'longitude': -122.302262}],
#  [{'city': 'Livermore',
#    'country_code': 'USA',
#    'latitude': 37.661237,
#    'longitude': -121.803572}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.566879,
#    'longitude': -122.323895}],
#  [{'city': 'Sunnyvale',
#    'country_code': 'USA',
#    'latitude': 37.384239,
#    'longitude': -122.012475}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': 37.418491,
#    'longitude': -122.08744}],
#  [{'city': 'Irving',
#    'country_code': 'USA',
#    'latitude': 32.860831,
#    'longitude': -96.9403}],
#  [{'city': 'Marina del Rey',
#    'country_code': 'USA',
#    'latitude': 33.977854,
#    'longitude': -118.445271}],
#  [{'city': 'Cambridge',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.779558,
#    'longitude': -122.393041}],
#  [{'city': 'Reno',
#    'country_code': 'USA',
#    'latitude': 39.530368,
#    'longitude': -119.81439}],
#  [{'city': 'Sunnyvale',
#    'country_code': 'USA',
#    'latitude': 37.369195,
#    'longitude': -122.036849}],
#  [{'city': None,
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Baltimore',
#    'country_code': 'USA',
#    'latitude': 39.281734,
#    'longitude': -76.581864}],
#  [{'city': 'London',
#    'country_code': 'GBR',
#    'latitude': 51.54236,
#    'longitude': -0.149522}],
#  [{'city': '',
#    'country_code': 'NZL',
#    'latitude': -37.797384,
#    'longitude': 175.2604}],
#  [{'city': 'Tel Aviv',
#    'country_code': 'ISR',
#    'latitude': 32.0554,
#    'longitude': 34.7595}],
#  [{'city': 'Melbourne',
#    'country_code': 'USA',
#    'latitude': 28.074742,
#    'longitude': -80.632606}],
#  [{'city': 'Mill Valley',
#    'country_code': 'USA',
#    'latitude': 37.904468,
#    'longitude': -122.542491}],
#  [{'city': 'Singer Island',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Van Nuys',
#    'country_code': 'USA',
#    'latitude': 34.210785,
#    'longitude': -118.474261}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': 37.401355,
#    'longitude': -122.104099}],
#  [{'city': 'Needham',
#    'country_code': 'USA',
#    'latitude': 42.304545,
#    'longitude': -71.220187}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.745216,
#    'longitude': -73.982807}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.792262,
#    'longitude': -122.403486}],
#  [{'city': 'Santa Clara',
#    'country_code': 'USA',
#    'latitude': 37.396312,
#    'longitude': -121.961396},
#   {'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 47.603015,
#    'longitude': -122.335668}],
#  [{'city': 'Wellington',
#    'country_code': 'NZL',
#    'latitude': -41.28648,
#    'longitude': 174.776217}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': 37.384919,
#    'longitude': -122.053175}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.775196,
#    'longitude': -122.419204}],
#  [{'city': 'los angeles',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': None,
#    'country_code': 'GBR',
#    'latitude': 55.378051,
#    'longitude': -3.435973}],
#  [],
#  [{'city': 'Hayward',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': 37.39248,
#    'longitude': -122.072612}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.775196,
#    'longitude': -122.419204}],
#  [{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 47.733603,
#    'longitude': -122.355579},
#   {'city': 'London',
#    'country_code': 'GBR',
#    'latitude': 51.524323,
#    'longitude': -0.081169}],
#  [{'city': '', 'country_code': 'USA', 'latitude': None, 'longitude': None}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
# ...
#  [{'city': 'Los Gatos',
#    'country_code': 'USA',
#    'latitude': 37.25142,
#    'longitude': -121.968687}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 33.988735,
#    'longitude': -118.368871},
#   {'city': 'New York',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Chicago',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Toronto',
#    'country_code': 'CAN',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Sydney',
#    'country_code': 'AUS',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'London',
#    'country_code': 'GBR',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Montreal',
#    'country_code': 'CAN',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Rotterdam',
#    'country_code': 'NLD',
#    'latitude': 51.919413,
#    'longitude': 4.45585}],
#  [{'city': 'Shanghai',
#    'country_code': 'CHN',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'La Jolla',
#    'country_code': 'USA',
#    'latitude': 32.874543,
#    'longitude': -117.214722}],
#  [{'city': 'Ladera Ranch',
#    'country_code': 'USA',
#    'latitude': 33.551221,
#    'longitude': -117.632731}],
#  [{'city': '',
#    'country_code': 'USA',
#    'latitude': 37.09024,
#    'longitude': -95.712891}],
#  [{'city': 'Tel Aviv',
#    'country_code': 'ISR',
#    'latitude': 32.0554,
#    'longitude': 34.7595}],
#  [{'city': 'San Jose',
#    'country_code': 'USA',
#    'latitude': 37.332828,
#    'longitude': -121.884399}],
#  [{'city': 'Austin',
#    'country_code': 'USA',
#    'latitude': 30.379593,
#    'longitude': -97.765313}],
#  [{'city': 'West Hollywood',
#    'country_code': 'USA',
#    'latitude': 34.090228,
#    'longitude': -118.393843}],
#  [{'city': 'Scottsdale',
#    'country_code': 'EGY',
#    'latitude': 33.5060338,
#    'longitude': -111.9261618}],
#  [{'city': 'Bangalore',
#    'country_code': 'IND',
#    'latitude': 35.929723,
#    'longitude': 139.605025}],
#  [{'city': 'London',
#    'country_code': 'GBR',
#    'latitude': 52.4624161,
#    'longitude': 1.696829}],
#  [{'city': 'Cupertino',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Washington',
#    'country_code': 'USA',
#    'latitude': 38.920066,
#    'longitude': -77.072331}],
#  [{'city': 'Boston',
#    'country_code': 'USA',
#    'latitude': 42.358283,
#    'longitude': -71.061688}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 37.446823,
#    'longitude': -122.161523},
#   {'city': 'Beverly Hills',
#    'country_code': 'USA',
#    'latitude': 34.0698494,
#    'longitude': -118.4054182}],
#  [{'city': 'Fullerton',
#    'country_code': 'USA',
#    'latitude': 33.874609,
#    'longitude': -117.881607}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.425168,
#    'longitude': -122.136248}],
#  [{'city': 'North Miami Beach',
#    'country_code': 'USA',
#    'latitude': 25.929683,
#    'longitude': -80.168256}],
#  [],
#  [{'city': '',
#    'country_code': 'CHN',
#    'latitude': 35.86166,
#    'longitude': 104.195397}],
#  [{'city': '',
#    'country_code': 'ISR',
#    'latitude': 31.046051,
#    'longitude': 34.851612}],
#  [{'city': 'Millstone Township',
#    'country_code': 'USA',
#    'latitude': 40.219214,
#    'longitude': -74.370313}],
#  [{'city': 'Bradenton',
#    'country_code': 'USA',
#    'latitude': 27.434873,
#    'longitude': -82.580968}],
#  [{'city': 'Mumbai',
#    'country_code': 'IND',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.7759675,
#    'longitude': -122.3931128}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.560781,
#    'longitude': -122.284114}],
#  [{'city': 'Millstone Township',
#    'country_code': 'USA',
#    'latitude': 40.219214,
#    'longitude': -74.370313}],
#  [{'city': 'Liverpool',
#    'country_code': 'GBR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.7862705,
#    'longitude': -122.3975827}],
#  [{'city': 'Amman',
#    'country_code': 'JOR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Seattle',
#    'country_code': 'USA',
#    'latitude': 47.620716,
#    'longitude': -122.347533}],
#  [{'city': 'Vancouver',
#    'country_code': 'CAN',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Coral Gables',
#    'country_code': 'USA',
#    'latitude': 25.705057,
#    'longitude': -80.271378}],
#  [{'city': 'Sunnyvale',
#    'country_code': 'USA',
#    'latitude': 37.380941,
#    'longitude': -122.010729}],
#  [{'city': 'Roswell',
#    'country_code': 'USA',
#    'latitude': 34.016362,
#    'longitude': -84.322687}],
#  [{'city': 'London',
#    'country_code': 'GBR',
#    'latitude': 51.523676,
#    'longitude': -0.107843}],
#  [{'city': 'Austin',
#    'country_code': 'USA',
#    'latitude': 30.27646,
#    'longitude': -97.746387}],
#  [{'city': 'Scotts Valley',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Jose',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Palma de Mallorca',
#    'country_code': 'ESP',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Raleigh',
#    'country_code': 'USA',
#    'latitude': 35.898459,
#    'longitude': -78.650931}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.775196,
#    'longitude': -122.419204}],
#  [{'city': 'Allentown',
#    'country_code': 'USA',
#    'latitude': 40.58471,
#    'longitude': -75.588974},
#   {'city': 'Allentown',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Port Huron',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Givataym',
#    'country_code': 'ISR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Minneapolis',
#    'country_code': 'USA',
#    'latitude': 44.977482,
#    'longitude': -93.264351}],
#  [{'city': 'Sewickley',
#    'country_code': 'USA',
#    'latitude': 40.61323,
#    'longitude': -80.101527}],
#  [{'city': 'Framingham',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': '',
#    'country_code': 'CZE',
#    'latitude': 49.817492,
#    'longitude': 15.472962}],
#  [{'city': 'Lincoln',
#    'country_code': 'USA',
#    'latitude': 40.748578,
#    'longitude': -96.666242}],
#  [{'city': 'London',
#    'country_code': 'GBR',
#    'latitude': 51.5211159,
#    'longitude': -0.0778345}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.451013,
#    'longitude': -122.120699}],
#  [{'city': 'Edmonton, Alberta',
#    'country_code': 'CAN',
#    'latitude': 53.4665377,
#    'longitude': -113.5291728}],
#  [{'city': 'Cambridge',
#    'country_code': 'USA',
#    'latitude': 42.36787,
#    'longitude': -71.078258}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.795236,
#    'longitude': -122.403607}],
#  [{'city': 'Newton',
#    'country_code': 'USA',
#    'latitude': 42.337037,
#    'longitude': -71.251748}],
#  [{'city': '',
#    'country_code': 'USA',
#    'latitude': 37.269175,
#    'longitude': -119.306607}],
#  [{'city': 'Seoul',
#    'country_code': 'KOR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Paris',
#    'country_code': 'FRA',
#    'latitude': 48.882647,
#    'longitude': 2.322551}],
#  [{'city': 'San Diego',
#    'country_code': 'USA',
#    'latitude': 32.936973,
#    'longitude': -117.240431}],
#  [{'city': 'London',
#    'country_code': 'GBR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Austin',
#    'country_code': 'USA',
#    'latitude': 30.268735,
#    'longitude': -97.745209}],
#  [{'city': 'Gainesville',
#    'country_code': 'USA',
#    'latitude': 29.6502461,
#    'longitude': -82.3230981}],
#  [],
#  [{'city': 'Burlingame',
#    'country_code': 'USA',
#    'latitude': 37.590056,
#    'longitude': -122.347654}],
#  [{'city': 'Berkeley',
#    'country_code': 'USA',
#    'latitude': 37.87168,
#    'longitude': -122.269494}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.7431477,
#    'longitude': -73.9934288}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.534317,
#    'longitude': -122.294847}],
#  [{'city': 'Redwood City',
#    'country_code': 'USA',
#    'latitude': 37.386774,
#    'longitude': -121.987661}],
#  [],
#  [],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 34.029209,
#    'longitude': -118.289344}],
#  [{'city': 'Stockholm',
#    'country_code': 'SWE',
#    'latitude': 59.336527,
#    'longitude': 18.077451}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': 37.40384,
#    'longitude': -122.07808}],
#  [{'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': 37.428373,
#    'longitude': -122.097604},
#   {'city': 'San Diego',
#    'country_code': 'USA',
#    'latitude': 32.957695,
#    'longitude': -117.158245}],
#  [{'city': 'Los Angeles',
#    'country_code': 'USA',
#    'latitude': 33.954874,
#    'longitude': -118.396507}],
#  [{'city': 'Oakland',
#    'country_code': 'USA',
#    'latitude': 37.810949,
#    'longitude': -122.26706}],
#  [{'city': 'Minneapolis',
#    'country_code': 'USA',
#    'latitude': 44.977482,
#    'longitude': -93.264351}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.744639,
#    'longitude': -73.983963}],
#  [{'city': 'Aachen',
#    'country_code': 'DEU',
#    'latitude': 50.791481,
#    'longitude': 6.066681}],
#  [{'city': 'Los Gatos',
#    'country_code': 'USA',
#    'latitude': 40.757929,
#    'longitude': -73.985506}],
#  [{'city': 'Sacramento',
#    'country_code': 'USA',
#    'latitude': 37.444188,
#    'longitude': -122.163745},
#   {'city': 'Paddington',
#    'country_code': 'AUS',
#    'latitude': -27.460736,
#    'longitude': 153.004254},
#   {'city': 'Maidenhead',
#    'country_code': 'GBR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Abercynon',
#    'country_code': 'GBR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Cork',
#    'country_code': 'IRL',
#    'latitude': 51.8892282,
#    'longitude': -8.5240303}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.723652,
#    'longitude': -73.985281}],
#  [{'city': 'Las Vegas',
#    'country_code': 'USA',
#    'latitude': 36.225757,
#    'longitude': -115.217851}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.757929,
#    'longitude': -73.985506}],
#  [{'city': 'Del Mar',
#    'country_code': 'USA',
#    'latitude': 34.423403,
#    'longitude': -119.704416}],
#  [{'city': 'Woodbridge',
#    'country_code': 'USA',
#    'latitude': 38.6581,
#    'longitude': -77.2501}],
#  [{'city': 'Birmingham',
#    'country_code': 'USA',
#    'latitude': 33.477448,
#    'longitude': -86.819367}],
#  [{'city': 'Oslo',
#    'country_code': 'NOR',
#    'latitude': 59.928267,
#    'longitude': 10.754932},
#   {'city': 'Oslo', 'country_code': 'DEU', 'latitude': None, 'longitude': None},
#   {'city': 'Linköping',
#    'country_code': 'SWE',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Göteborg',
#    'country_code': 'SWE',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Mountain View',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'San Diego',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Tokyo',
#    'country_code': 'JPN',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Beijing',
#    'country_code': 'CHN',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Seoul',
#    'country_code': 'KOR',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Chandigarh',
#    'country_code': 'IND',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Warsaw',
#    'country_code': 'POL',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Wrocław',
#    'country_code': 'POL',
#    'latitude': None,
#    'longitude': None},
#   {'city': 'Taipei',
#    'country_code': 'TWN',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Austin',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Austin',
#    'country_code': 'USA',
#    'latitude': 30.414146,
#    'longitude': -97.807032}],
#  [{'city': 'Causeway Bay',
#    'country_code': 'HKG',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Victoria, BC',
#    'country_code': 'CAN',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.4784804,
#    'longitude': -122.1514101}],
#  [{'city': 'Kauniainen',
#    'country_code': 'FIN',
#    'latitude': 60.214102,
#    'longitude': 24.704663}],
#  [{'city': 'Philadelphia',
#    'country_code': 'USA',
#    'latitude': 39.951639,
#    'longitude': -75.163808}],
#  [{'city': 'Helsinki',
#    'country_code': 'FIN',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Van Nuys',
#    'country_code': 'USA',
#    'latitude': 34.19099,
#    'longitude': -118.486428}],
#  [{'city': 'sydney',
#    'country_code': 'AUS',
#    'latitude': -33.884685,
#    'longitude': 151.216427}],
#  [{'city': 'Alhambra',
#    'country_code': 'USA',
#    'latitude': 34.091562,
#    'longitude': -118.13461}],
#  [{'city': 'San Mateo',
#    'country_code': 'USA',
#    'latitude': 37.54763,
#    'longitude': -122.307887}],
#  [{'city': 'San Diego',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Herndon',
#    'country_code': 'USA',
#    'latitude': 38.95424,
#    'longitude': -77.416331}],
#  [{'city': 'Washington',
#    'country_code': 'USA',
#    'latitude': 38.904592,
#    'longitude': -77.038503}],
#  [{'city': 'London',
#    'country_code': 'GBR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Redwood City',
#    'country_code': 'USA',
#    'latitude': 37.503147,
#    'longitude': -122.211435}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.775196,
#    'longitude': -122.419204}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'Toulon',
#    'country_code': 'FRA',
#    'latitude': 43.124351,
#    'longitude': 5.929313}],
#  [{'city': 'New York City',
#    'country_code': 'USA',
#    'latitude': 40.757929,
#    'longitude': -73.985506},
#   {'city': 'Netanya',
#    'country_code': 'ISR',
#    'latitude': None,
#    'longitude': None}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 37.783151,
#    'longitude': -122.393323}],
#  [{'city': 'San Diego',
#    'country_code': 'USA',
#    'latitude': 32.880882,
#    'longitude': -117.203309}],
#  [{'city': 'Sunnyvale',
#    'country_code': 'USA',
#    'latitude': 37.386376,
#    'longitude': -121.991471}],
#  [{'city': 'Palo Alto',
#    'country_code': 'USA',
#    'latitude': 37.445326,
#    'longitude': -122.160671}],
#  [{'city': 'Austin',
#    'country_code': 'USA',
#    'latitude': 30.26652,
#    'longitude': -97.7429367}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.757929,
#    'longitude': -73.985506}],
#  [{'city': 'Bend',
#    'country_code': 'USA',
#    'latitude': 44.059936,
#    'longitude': -121.307839}],
#  [],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.735537,
#    'longitude': -74.006179}],
#  [],
#  [{'city': '',
#    'country_code': 'USA',
#    'latitude': 37.419156,
#    'longitude': -122.075413}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': 40.8587524,
#    'longitude': -73.7258199}],
#  [{'city': '',
#    'country_code': 'USA',
#    'latitude': 32.6460331,
#    'longitude': -16.9147342}],
#  [{'city': 'Pittsburgh',
#    'country_code': 'USA',
#    'latitude': 40.431653,
#    'longitude': -79.915015}],
#  [{'city': '',
#    'country_code': 'USA',
#    'latitude': 37.378943,
#    'longitude': -121.92401}],
#  [{'city': 'San Francisco',
#    'country_code': 'USA',
#    'latitude': 41.948365,
#    'longitude': -87.646307}],
#  [{'city': 'Midland',
#    'country_code': 'USA',
#    'latitude': 43.626128,
#    'longitude': -84.227415}],
#  [{'city': 'Fremont',
#    'country_code': 'USA',
#    'latitude': 37.548615,
#    'longitude': -121.988479}],
#  [{'city': 'Wilmington',
#    'country_code': 'USA',
#    'latitude': 39.748985,
#    'longitude': -75.546329}],
#  [{'city': 'New York',
#    'country_code': 'USA',
#    'latitude': None,
#    'longitude': None}],
#  ...]

# %%
city[0][0]
# Out:
# {'city': 'Seattle',
#  'country_code': 'USA',
#  'latitude': 47.603122,
#  'longitude': -122.333253}

# %%
list_cities=[j for i in city for j in i]
list_cities
# Out:
# [{'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.603122,
#   'longitude': -122.333253},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.7237306,
#   'longitude': -73.9964312},
#  {'city': 'Pleasanton',
#   'country_code': 'USA',
#   'latitude': 37.692934,
#   'longitude': -121.904945},
#  {'city': 'San Carlos',
#   'country_code': 'USA',
#   'latitude': 37.506885,
#   'longitude': -122.247573},
#  {'city': 'West Hollywood',
#   'country_code': 'USA',
#   'latitude': 34.090368,
#   'longitude': -118.393064},
#  {'city': 'Culver City',
#   'country_code': 'USA',
#   'latitude': 34.025958,
#   'longitude': -118.379768},
#  {'city': 'Beverly Hills',
#   'country_code': 'USA',
#   'latitude': 34.076179,
#   'longitude': -118.39417},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.775196,
#   'longitude': -122.419204},
#  {'city': 'New York City',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Menlo Park',
#   'country_code': 'USA',
#   'latitude': 37.48413,
#   'longitude': -122.169472},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.451151,
#   'longitude': -122.154369},
#  {'city': 'San Jose',
#   'country_code': 'USA',
#   'latitude': 37.295005,
#   'longitude': -121.930035},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.7464969,
#   'longitude': -74.0094471},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.757725,
#   'longitude': -73.986011},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': 53.344104,
#   'longitude': -6.267494},
#  {'city': 'Sunnyvale',
#   'country_code': 'USA',
#   'latitude': 37.387845,
#   'longitude': -122.055197},
#  {'city': 'Sunnyvale',
#   'country_code': 'USA',
#   'latitude': 37.418531,
#   'longitude': -122.025485},
#  {'city': 'Culver City',
#   'country_code': 'USA',
#   'latitude': 34.017606,
#   'longitude': -118.487267},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.788482,
#   'longitude': -122.409173},
#  {'city': 'San Diego',
#   'country_code': 'USA',
#   'latitude': 32.902266,
#   'longitude': -117.20834},
#  {'city': 'McLean',
#   'country_code': 'USA',
#   'latitude': 38.929289,
#   'longitude': -77.216585},
#  {'city': 'Austin',
#   'country_code': 'USA',
#   'latitude': 30.268735,
#   'longitude': -97.745209},
#  {'city': 'Chicago',
#   'country_code': 'USA',
#   'latitude': 41.885619,
#   'longitude': -87.622309},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.437328,
#   'longitude': -122.159928},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.72604,
#   'longitude': -73.995722},
#  {'city': 'Sunnyvale',
#   'country_code': 'USA',
#   'latitude': 37.384239,
#   'longitude': -122.012475},
#  {'city': '',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.793148,
#   'longitude': -122.402567},
#  {'city': 'Pleasanton',
#   'country_code': 'USA',
#   'latitude': 37.697805,
#   'longitude': -121.907768},
#  {'city': 'Luxembourg City',
#   'country_code': 'LUX',
#   'latitude': 51.518132,
#   'longitude': -0.131916},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Bruno',
#   'country_code': 'USA',
#   'latitude': 37.627971,
#   'longitude': -122.426804},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 34.051409,
#   'longitude': -118.254558},
#  {'city': 'Ramat Gan',
#   'country_code': 'ISR',
#   'latitude': 31.046051,
#   'longitude': 34.851612},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.726155,
#   'longitude': -73.995625},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.392936,
#   'longitude': -122.07948},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Budapest',
#   'country_code': 'HUN',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'NYC',
#   'country_code': 'USA',
#   'latitude': 40.801358,
#   'longitude': -74.3372},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.722655,
#   'longitude': -73.99873},
#  {'city': 'Stamford',
#   'country_code': 'USA',
#   'latitude': 41.049051,
#   'longitude': -73.563878},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.44296,
#   'longitude': -122.151198},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.762541,
#   'longitude': -122.397224},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.757758,
#   'longitude': -122.388243},
#  {'city': 'Oxford',
#   'country_code': 'GBR',
#   'latitude': 51.752276,
#   'longitude': -1.255824},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.269175,
#   'longitude': -119.306607},
#  {'city': 'Encino',
#   'country_code': 'USA',
#   'latitude': 37.269175,
#   'longitude': -119.306607},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.780716,
#   'longitude': -122.393913},
#  {'city': 'Moscow',
#   'country_code': 'RUS',
#   'latitude': 55.755786,
#   'longitude': 37.617633},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': 37.553385,
#   'longitude': -122.302149},
#  {'city': '46395 Bocholt',
#   'country_code': 'DEU',
#   'latitude': 51.808933,
#   'longitude': 6.553452},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': 37.421621,
#   'longitude': -122.137444},
#  {'city': 'Dublin',
#   'country_code': 'IRL',
#   'latitude': 53.354997,
#   'longitude': -6.229255},
#  {'city': 'Burlingame',
#   'country_code': 'USA',
#   'latitude': 37.590339,
#   'longitude': -122.341715},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.793819,
#   'longitude': -122.395089},
#  {'city': 'Agoura Hills',
#   'country_code': 'USA',
#   'latitude': 34.155211,
#   'longitude': -118.756618},
#  {'city': 'Toronto, Ontario',
#   'country_code': 'CAN',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Santa Clara',
#   'country_code': 'USA',
#   'latitude': 37.380101,
#   'longitude': -121.940749},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 34.052187,
#   'longitude': -118.243425},
#  {'city': 'Amsterdam',
#   'country_code': 'NLD',
#   'latitude': 52.3745228,
#   'longitude': 4.8948623},
#  {'city': 'Amsterdam',
#   'country_code': 'NLD',
#   'latitude': 52.375595,
#   'longitude': 4.908556},
#  {'city': 'Redwood City',
#   'country_code': 'USA',
#   'latitude': 37.476479,
#   'longitude': -122.221717},
#  {'city': 'Southampton',
#   'country_code': 'GBR',
#   'latitude': 50.9444598,
#   'longitude': -1.3610845},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.775196,
#   'longitude': -122.419204},
#  {'city': 'Santa Clara',
#   'country_code': 'USA',
#   'latitude': 37.374998,
#   'longitude': -121.977853},
#  {'city': 'Sunnyvale',
#   'country_code': 'USA',
#   'latitude': 37.36965,
#   'longitude': -122.02421},
#  {'city': 'Redwood City',
#   'country_code': 'USA',
#   'latitude': 37.484619,
#   'longitude': -122.206893},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.758113,
#   'longitude': -122.414689},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.7791761,
#   'longitude': -122.4058887},
#  {'city': 'Paris',
#   'country_code': 'FRA',
#   'latitude': 48.870806,
#   'longitude': 2.34668},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.781427,
#   'longitude': -122.392144},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.782103,
#   'longitude': -122.401116},
#  {'city': 'Sunnyvale',
#   'country_code': 'USA',
#   'latitude': 37.418531,
#   'longitude': -122.025485},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.778076,
#   'longitude': -122.397977},
#  {'city': '',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.614653,
#   'longitude': -122.338793},
#  {'city': 'Mill Valley',
#   'country_code': 'USA',
#   'latitude': 37.90077,
#   'longitude': -122.511687},
#  {'city': 'Chicago',
#   'country_code': 'USA',
#   'latitude': 41.889474,
#   'longitude': -87.628912},
#  {'city': 'Paris',
#   'country_code': 'FRA',
#   'latitude': 48.856667,
#   'longitude': 2.350987},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.762681,
#   'longitude': -122.400909},
#  {'city': 'Paris',
#   'country_code': 'FRA',
#   'latitude': 48.866323,
#   'longitude': 2.381514},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.796396,
#   'longitude': -122.404869},
#  {'city': 'Mountain View',
#   'country_code': 'USA',
#   'latitude': 37.393679,
#   'longitude': -122.079017},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Santa Monica',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Chicago',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.779507,
#   'longitude': -122.39071},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.618599,
#   'longitude': -122.358484},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.437328,
#   'longitude': -122.159928},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.615313,
#   'longitude': -122.323408},
#  {'city': 'West Hollywood',
#   'country_code': 'USA',
#   'latitude': 34.0906602,
#   'longitude': -118.3835957},
#  {'city': 'San Diego',
#   'country_code': 'USA',
#   'latitude': 32.718834,
#   'longitude': -117.163841},
#  {'city': 'Tel Aviv',
#   'country_code': 'ISR',
#   'latitude': 32.0554,
#   'longitude': 34.7595},
#  {'city': 'Geneva',
#   'country_code': 'CHE',
#   'latitude': 46.20381,
#   'longitude': 6.139959},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.775196,
#   'longitude': -122.419204},
#  {'city': 'Cincinnati',
#   'country_code': 'USA',
#   'latitude': 39.06685,
#   'longitude': -84.351532},
#  {'city': 'Charlottesville',
#   'country_code': 'USA',
#   'latitude': 38.030823,
#   'longitude': -78.48158},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': 37.553121,
#   'longitude': -122.301534},
#  {'city': 'Burlingame',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.7618242,
#   'longitude': -122.3985871},
#  {'city': 'San Diego',
#   'country_code': 'USA',
#   'latitude': 32.872081,
#   'longitude': -117.206292},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Diego',
#   'country_code': 'USA',
#   'latitude': 39.9195028,
#   'longitude': -105.1110024},
#  {'city': 'Redwood City',
#   'country_code': 'USA',
#   'latitude': 37.479952,
#   'longitude': -122.178557},
#  {'city': 'Knoxville',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.76785,
#   'longitude': -122.392861},
#  {'city': 'Vashon',
#   'country_code': 'USA',
#   'latitude': 47.420728,
#   'longitude': -122.450942},
#  {'city': 'Woodland Hills',
#   'country_code': 'USA',
#   'latitude': 34.184598,
#   'longitude': -118.601532},
#  {'city': '',
#   'country_code': 'USA',
#   'latitude': 34.070436,
#   'longitude': -118.350486},
#  {'city': 'Los Gatos',
#   'country_code': 'USA',
#   'latitude': 37.255118,
#   'longitude': -121.96533},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.782263,
#   'longitude': -122.392142},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.766909,
#   'longitude': -122.406676},
#  {'city': 'Arlington',
#   'country_code': 'USA',
#   'latitude': 38.897428,
#   'longitude': -77.072003},
#  {'city': 'Mill Valley',
#   'country_code': 'USA',
#   'latitude': 37.905544,
#   'longitude': -122.547445},
#  {'city': 'Seoul', 'country_code': 'KOR', 'latitude': None, 'longitude': None},
#  {'city': 'Mountain View',
#   'country_code': 'USA',
#   'latitude': 37.40047,
#   'longitude': -122.072981},
#  {'city': 'Austin',
#   'country_code': 'USA',
#   'latitude': 30.407545,
#   'longitude': -97.717667},
#  {'city': 'Pleasanton',
#   'country_code': 'USA',
#   'latitude': 37.6637279,
#   'longitude': -121.8731805},
#  {'city': 'Reston',
#   'country_code': 'USA',
#   'latitude': 38.9590083,
#   'longitude': -77.3592746},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': 51.5170385,
#   'longitude': -0.1394759},
#  {'city': 'London W11 2HX',
#   'country_code': 'GBR',
#   'latitude': 51.514935,
#   'longitude': -0.205349},
#  {'city': 'San Jose',
#   'country_code': 'USA',
#   'latitude': 37.321798,
#   'longitude': -121.979453},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': 51.500152,
#   'longitude': -0.126236},
#  {'city': 'Bellevue',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.788668,
#   'longitude': -122.400558},
#  {'city': 'Bagnacavallo',
#   'country_code': 'ITA',
#   'latitude': 44.418166,
#   'longitude': 11.978686},
#  {'city': None,
#   'country_code': 'JPN',
#   'latitude': 36.204824,
#   'longitude': 138.252924},
#  {'city': 'Stamford',
#   'country_code': 'USA',
#   'latitude': 41.038155,
#   'longitude': -73.558082},
#  {'city': 'Austin',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.774321,
#   'longitude': -122.415375},
#  {'city': 'Montecito',
#   'country_code': 'USA',
#   'latitude': 34.42071,
#   'longitude': -119.641821},
#  {'city': 'Brighton',
#   'country_code': 'GBR',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Boston',
#   'country_code': 'USA',
#   'latitude': 42.355672,
#   'longitude': -71.060864},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': 37.55909,
#   'longitude': -122.321836},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.787092,
#   'longitude': -122.399972},
#  {'city': 'Huntsville',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': 37.536172,
#   'longitude': -122.327323},
#  {'city': 'Mill Valley',
#   'country_code': 'USA',
#   'latitude': 37.898575,
#   'longitude': -122.537302},
#  {'city': 'Amsterdam',
#   'country_code': 'NLD',
#   'latitude': 52.3640933,
#   'longitude': 4.8919457},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.787683,
#   'longitude': -122.410943},
#  {'city': 'Singapore',
#   'country_code': 'SGP',
#   'latitude': 51.500152,
#   'longitude': -0.126236},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Mountain View',
#   'country_code': 'USA',
#   'latitude': 37.419819,
#   'longitude': -122.090188},
#  {'city': 'San Jose',
#   'country_code': 'USA',
#   'latitude': 37.320052,
#   'longitude': -121.877636},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.779392,
#   'longitude': -122.417928},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': 37.4858654,
#   'longitude': -122.2262606},
#  {'city': 'Phoenix',
#   'country_code': 'USA',
#   'latitude': 33.429864,
#   'longitude': -111.944967},
#  {'city': 'Sunnyvale',
#   'country_code': 'USA',
#   'latitude': 37.386376,
#   'longitude': -121.991471},
#  {'city': 'Sunnyvale',
#   'country_code': 'USA',
#   'latitude': 37.384651,
#   'longitude': -121.992132},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.446687,
#   'longitude': -122.163189},
#  {'city': '',
#   'country_code': 'USA',
#   'latitude': 37.269175,
#   'longitude': -119.306607},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.408256,
#   'longitude': -122.154176},
#  {'city': 'Vancouver',
#   'country_code': 'CAN',
#   'latitude': 49.283376,
#   'longitude': -123.103986},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.5999337,
#   'longitude': -122.3276962},
#  {'city': 'Culver City',
#   'country_code': 'USA',
#   'latitude': 34.017506,
#   'longitude': -118.401579},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.736416,
#   'longitude': -73.993302},
#  {'city': 'Sydney',
#   'country_code': 'AUS',
#   'latitude': -33.722577,
#   'longitude': 150.981801},
#  {'city': 'Boulder',
#   'country_code': 'USA',
#   'latitude': 40.010492,
#   'longitude': -105.276843},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.780883,
#   'longitude': -122.395257},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.61968,
#   'longitude': -122.356756},
#  {'city': 'Sunnyvale',
#   'country_code': 'USA',
#   'latitude': 37.368594,
#   'longitude': -122.034021},
#  {'city': 'Mountain View',
#   'country_code': 'USA',
#   'latitude': 37.400465,
#   'longitude': -122.073003},
#  {'city': 'Mountain View',
#   'country_code': 'USA',
#   'latitude': 37.386665,
#   'longitude': -122.084171},
#  {'city': 'Redmond',
#   'country_code': 'USA',
#   'latitude': 47.672229,
#   'longitude': -122.115633},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.620716,
#   'longitude': -122.347533},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': 37.553743,
#   'longitude': -122.300246},
#  {'city': 'Tel Aviv',
#   'country_code': 'ISR',
#   'latitude': 32.0554,
#   'longitude': 34.7595},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Burbank',
#   'country_code': 'USA',
#   'latitude': 34.156802,
#   'longitude': -118.324987},
#  {'city': 'Singapore',
#   'country_code': 'SGP',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Waltham',
#   'country_code': 'USA',
#   'latitude': 42.417268,
#   'longitude': -71.258466},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 34.052187,
#   'longitude': -118.243425},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'West Hollywood',
#   'country_code': 'USA',
#   'latitude': 34.090932,
#   'longitude': -118.38428},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.7311317,
#   'longitude': -73.9919311},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.437328,
#   'longitude': -122.159928},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'El Segundo',
#   'country_code': 'USA',
#   'latitude': 33.920296,
#   'longitude': -118.391852},
#  {'city': 'Atlanta',
#   'country_code': 'USA',
#   'latitude': 33.916374,
#   'longitude': -84.350663},
#  {'city': 'Mountain View',
#   'country_code': 'USA',
#   'latitude': 37.3927975,
#   'longitude': -122.0727749},
#  {'city': 'Boulder',
#   'country_code': 'USA',
#   'latitude': 40.010492,
#   'longitude': -105.276843},
#  {'city': None,
#   'country_code': 'ISR',
#   'latitude': 31.046051,
#   'longitude': 34.851612},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.437328,
#   'longitude': -122.159928},
#  {'city': 'Woodbridge',
#   'country_code': 'CAN',
#   'latitude': 43.76969,
#   'longitude': -79.549577},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Antonio',
#   'country_code': 'USA',
#   'latitude': 29.427051,
#   'longitude': -98.487764},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Newburyport',
#   'country_code': 'USA',
#   'latitude': 42.7973978,
#   'longitude': -70.8873327},
#  {'city': 'Las Vegas',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Helsinki',
#   'country_code': 'FIN',
#   'latitude': 60.165166,
#   'longitude': 24.945937},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Leeds', 'country_code': 'GBR', 'latitude': None, 'longitude': None},
#  {'city': '',
#   'country_code': 'ISR',
#   'latitude': 31.046051,
#   'longitude': 34.851612},
#  {'city': 'Venice',
#   'country_code': 'USA',
#   'latitude': 33.988337,
#   'longitude': -118.472721},
#  {'city': 'mem',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Naples',
#   'country_code': 'USA',
#   'latitude': 26.246414,
#   'longitude': -81.788104},
#  {'city': 'Atlanta',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Newport Beach',
#   'country_code': 'USA',
#   'latitude': 33.610083,
#   'longitude': -117.928351},
#  {'city': 'Arlington',
#   'country_code': 'USA',
#   'latitude': 38.892371,
#   'longitude': -77.081732},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 31.169036,
#   'longitude': -100.076888},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 34.052187,
#   'longitude': -118.243425},
#  {'city': 'Oceanside',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.437328,
#   'longitude': -122.159928},
#  {'city': 'Menlo Park',
#   'country_code': 'USA',
#   'latitude': 37.491356,
#   'longitude': -122.228843},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 34.101617,
#   'longitude': -118.327071},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.794649,
#   'longitude': -122.399646},
#  {'city': None,
#   'country_code': 'ISR',
#   'latitude': 17.08881,
#   'longitude': -96.76492},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.7909427,
#   'longitude': -122.4084994},
#  {'city': 'Dublin',
#   'country_code': 'IRL',
#   'latitude': None,
#   'longitude': None},
#  {'city': '',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Mountain View',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Menlo Park',
#   'country_code': 'USA',
#   'latitude': 37.48413,
#   'longitude': -122.169472},
#  {'city': '',
#   'country_code': 'ESP',
#   'latitude': 40.463667,
#   'longitude': -3.74922},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.780134,
#   'longitude': -122.396744},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.779507,
#   'longitude': -122.39071},
#  {'city': 'Ultimo',
#   'country_code': 'AUS',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Barcelona, 08019',
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Hamburg',
#   'country_code': 'DEU',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Tokyo', 'country_code': 'JPN', 'latitude': None, 'longitude': None},
#  {'city': 'Shanghai',
#   'country_code': 'CHN',
#   'latitude': None,
#   'longitude': None},
#  {'city': '', 'country_code': 'USA', 'latitude': None, 'longitude': None},
#  {'city': 'Redmond',
#   'country_code': 'USA',
#   'latitude': 47.682233,
#   'longitude': -122.135521},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.795555,
#   'longitude': -122.400729},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.7911148,
#   'longitude': -122.3954751},
#  {'city': 'Cape Town',
#   'country_code': 'ZAF',
#   'latitude': None,
#   'longitude': None},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 38.805114,
#   'longitude': -77.236968},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.790998,
#   'longitude': -122.394668},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.786942,
#   'longitude': -122.401245},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.781557,
#   'longitude': -122.407959},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 40.010492,
#   'longitude': -105.276843},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.383779,
#   'longitude': -122.007172},
#  {'city': 'Pittsburgh',
#   'country_code': 'USA',
#   'latitude': 40.445009,
#   'longitude': -79.948563},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.752957,
#   'longitude': -73.98546},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Durham',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Minneapolis',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Melbourne',
#   'country_code': 'AUS',
#   'latitude': -37.814251,
#   'longitude': 144.963169},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 34.062262,
#   'longitude': -118.348198},
#  {'city': 'San Diego',
#   'country_code': 'USA',
#   'latitude': 32.71537,
#   'longitude': -117.163353},
#  {'city': 'Paris',
#   'country_code': 'FRA',
#   'latitude': 48.856667,
#   'longitude': 2.350987},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.444554,
#   'longitude': -122.164511},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.427235,
#   'longitude': -122.145783},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.705898,
#   'longitude': -74.011398},
#  {'city': 'Andover',
#   'country_code': 'USA',
#   'latitude': 42.675189,
#   'longitude': -71.1469},
#  {'city': 'Henderson',
#   'country_code': 'USA',
#   'latitude': 36.032976,
#   'longitude': -115.064859},
#  {'city': 'Shepherdsville',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Bellevue',
#   'country_code': 'USA',
#   'latitude': 47.579208,
#   'longitude': -122.155668},
#  {'city': 'Santa Monica',
#   'country_code': 'USA',
#   'latitude': 34.018275,
#   'longitude': -118.495025},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.782263,
#   'longitude': -122.392142},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.610332,
#   'longitude': -122.339859},
#  {'city': 'Austin',
#   'country_code': 'USA',
#   'latitude': 30.268735,
#   'longitude': -97.745209},
#  {'city': 'Menlo Park',
#   'country_code': 'USA',
#   'latitude': 37.48413,
#   'longitude': -122.169472},
#  {'city': 'Mountain View',
#   'country_code': 'USA',
#   'latitude': 37.40047,
#   'longitude': -122.072981},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Belmont',
#   'country_code': 'USA',
#   'latitude': 37.524422,
#   'longitude': -122.265869},
#  {'city': 'Santa Monica',
#   'country_code': 'USA',
#   'latitude': 34.017373,
#   'longitude': -118.453218},
#  {'city': 'Fort Lauderdale',
#   'country_code': 'USA',
#   'latitude': 26.207024,
#   'longitude': -80.157296},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.790964,
#   'longitude': -122.401128},
#  {'city': 'Marina Del Rey',
#   'country_code': 'USA',
#   'latitude': 33.983543,
#   'longitude': -118.432526},
#  {'city': 'Santa Monica',
#   'country_code': 'USA',
#   'latitude': 34.145946,
#   'longitude': -118.132351},
#  {'city': 'Kuala Lumpur',
#   'country_code': 'MYS',
#   'latitude': 3.139003,
#   'longitude': 101.686855},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.753385,
#   'longitude': -73.98962},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.731118,
#   'longitude': -73.991933},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.731118,
#   'longitude': -73.991933},
#  {'city': 'Bath, Somerset',
#   'country_code': 'GBR',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Germantown',
#   'country_code': 'USA',
#   'latitude': 39.2009241,
#   'longitude': -77.2630048},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.746953,
#   'longitude': -73.993553},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 33.979033,
#   'longitude': -118.423423},
#  {'city': 'Marina Del Rey',
#   'country_code': 'USA',
#   'latitude': 33.979506,
#   'longitude': -118.439787},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': 37.554595,
#   'longitude': -122.317471},
#  {'city': 'Mountain View',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Chicago',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 55.378051,
#   'longitude': -3.435973},
#  {'city': 'Southlake',
#   'country_code': 'USA',
#   'latitude': 32.9819881,
#   'longitude': -97.1599393},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Glendale',
#   'country_code': 'USA',
#   'latitude': 34.155224,
#   'longitude': -118.255197},
#  {'city': 'Andover',
#   'country_code': 'USA',
#   'latitude': 42.656621,
#   'longitude': -71.140538},
#  {'city': 'Fort Lauderdale',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Boston',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Neuilly sur Seine',
#   'country_code': 'FRA',
#   'latitude': 48.882314,
#   'longitude': 2.2673953},
#  {'city': 'Corte Madera',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.785647,
#   'longitude': -122.405265},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Boston',
#   'country_code': 'USA',
#   'latitude': 42.350274,
#   'longitude': -71.058768},
#  {'city': 'Bellevue',
#   'country_code': 'USA',
#   'latitude': 47.597965,
#   'longitude': -122.151158},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Saint Louis',
#   'country_code': 'USA',
#   'latitude': 38.618874,
#   'longitude': -90.216499},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Bangalore',
#   'country_code': 'IND',
#   'latitude': 12.971606,
#   'longitude': 77.594376},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Arlington',
#   'country_code': 'USA',
#   'latitude': 42.417903,
#   'longitude': -71.164975},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.757929,
#   'longitude': -73.985506},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Waltham',
#   'country_code': 'USA',
#   'latitude': 42.393662,
#   'longitude': -71.255855},
#  {'city': 'Santa Monica',
#   'country_code': 'USA',
#   'latitude': 34.0184659,
#   'longitude': -118.49863},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'New  York',
#   'country_code': 'USA',
#   'latitude': 40.757929,
#   'longitude': -73.985506},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': 37.553743,
#   'longitude': -122.300246},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': 51.5192042,
#   'longitude': -0.1626103},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.433414,
#   'longitude': -122.128772},
#  {'city': 'Norcross',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.707921,
#   'longitude': -74.004792},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.775196,
#   'longitude': -122.419204},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.5999337,
#   'longitude': -122.3276962},
#  {'city': 'San Diego',
#   'country_code': 'USA',
#   'latitude': 32.901317,
#   'longitude': -117.200492},
#  {'city': 'Toronto',
#   'country_code': 'CAN',
#   'latitude': 43.799511,
#   'longitude': -79.348037},
#  {'city': 'San Jose',
#   'country_code': 'USA',
#   'latitude': 37.316466,
#   'longitude': -121.873881},
#  {'city': 'Newton',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Cerritos',
#   'country_code': 'AFG',
#   'latitude': None,
#   'longitude': None},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.723384,
#   'longitude': -74.001704},
#  {'city': 'Austin',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Sassenage',
#   'country_code': 'FRA',
#   'latitude': 45.206889,
#   'longitude': 5.659066},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.781265,
#   'longitude': -122.393229},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Brussel',
#   'country_code': 'BEL',
#   'latitude': 50.796645,
#   'longitude': 4.400604},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.74406,
#   'longitude': -74.004592},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Eden Prairie',
#   'country_code': 'USA',
#   'latitude': 44.865243,
#   'longitude': -93.4094629},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.447969,
#   'longitude': -122.119417},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 34.031276,
#   'longitude': -118.456806},
#  {'city': 'Mountain View',
#   'country_code': 'USA',
#   'latitude': 37.40047,
#   'longitude': -122.072981},
#  {'city': '', 'country_code': 'USA', 'latitude': None, 'longitude': None},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': 37.453687,
#   'longitude': -122.228595},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.753202,
#   'longitude': -73.986771},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.611012,
#   'longitude': -122.333523},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Cambridge',
#   'country_code': 'GBR',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.723703,
#   'longitude': -73.99644},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Frankfurt am Main',
#   'country_code': 'DEU',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Boulder',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Portland',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Or Yehuda',
#   'country_code': 'ISR',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Austin',
#   'country_code': 'USA',
#   'latitude': 30.34497,
#   'longitude': -97.770174},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'McLean',
#   'country_code': 'USA',
#   'latitude': 38.003376,
#   'longitude': -79.420926},
#  {'city': 'Boulder',
#   'country_code': 'USA',
#   'latitude': 40.048078,
#   'longitude': -105.38018},
#  {'city': 'New London',
#   'country_code': 'USA',
#   'latitude': 41.345754,
#   'longitude': -72.105722},
#  {'city': 'Chicago',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'La Jolla',
#   'country_code': 'USA',
#   'latitude': 32.847521,
#   'longitude': -117.274609},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 34.0481711,
#   'longitude': -118.4419012},
#  {'city': 'METZ',
#   'country_code': 'FRA',
#   'latitude': 49.1004,
#   'longitude': 6.182658},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.793742,
#   'longitude': -122.421341},
#  {'city': 'Toronto',
#   'country_code': 'CAN',
#   'latitude': 43.6501051,
#   'longitude': -79.396805},
#  {'city': 'Portland',
#   'country_code': 'USA',
#   'latitude': 45.5241278,
#   'longitude': -122.675448},
#  {'city': 'Rockville',
#   'country_code': 'USA',
#   'latitude': 39.052614,
#   'longitude': -77.123153},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.6015315,
#   'longitude': -122.335943},
#  {'city': '',
#   'country_code': 'CAN',
#   'latitude': 56.130366,
#   'longitude': -106.346771},
#  {'city': 'Berlin',
#   'country_code': 'DEU',
#   'latitude': 52.5013449,
#   'longitude': 13.4109071},
#  {'city': 'Hannover',
#   'country_code': 'DEU',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'The Woodlands',
#   'country_code': 'USA',
#   'latitude': 30.182107,
#   'longitude': -95.536},
#  {'city': 'Santa Monica',
#   'country_code': 'USA',
#   'latitude': 34.01052,
#   'longitude': -118.495981},
#  {'city': 'Sammamish',
#   'country_code': 'USA',
#   'latitude': 47.585114,
#   'longitude': -122.084356},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 33.959799,
#   'longitude': -118.343938},
#  {'city': 'Paris',
#   'country_code': 'FRA',
#   'latitude': 48.8558532,
#   'longitude': 2.3365754},
#  {'city': 'Chicago',
#   'country_code': 'USA',
#   'latitude': 41.890376,
#   'longitude': -87.63406},
#  {'city': 'Needham',
#   'country_code': 'USA',
#   'latitude': 42.296111,
#   'longitude': -71.238524},
#  {'city': 'Boulder',
#   'country_code': 'USA',
#   'latitude': 40.010492,
#   'longitude': -105.276843},
#  {'city': 'Redmond',
#   'country_code': 'USA',
#   'latitude': 47.672229,
#   'longitude': -122.115633},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.786175,
#   'longitude': -122.389676},
#  {'city': 'West Palm Beach',
#   'country_code': 'USA',
#   'latitude': 43.67084,
#   'longitude': -83.913153},
#  {'city': 'Sunnyvale',
#   'country_code': 'USA',
#   'latitude': 37.368594,
#   'longitude': -122.034021},
#  {'city': 'Cambridge',
#   'country_code': 'USA',
#   'latitude': 42.375392,
#   'longitude': -71.118487},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': 51.523789,
#   'longitude': -0.087432},
#  {'city': 'Tokyo',
#   'country_code': 'JPN',
#   'latitude': 35.6158956,
#   'longitude': 139.7492374},
#  {'city': '', 'country_code': 'GBR', 'latitude': None, 'longitude': None},
#  {'city': '', 'country_code': 'JOR', 'latitude': None, 'longitude': None},
#  {'city': 'Tokyo', 'country_code': 'JPN', 'latitude': None, 'longitude': None},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Westlake Village',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': 51.519819,
#   'longitude': -0.136174},
#  {'city': 'Singapore',
#   'country_code': 'SGP',
#   'latitude': 37.580304,
#   'longitude': -122.343679},
#  {'city': 'Cambridge',
#   'country_code': 'USA',
#   'latitude': 42.375392,
#   'longitude': -71.118487},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 36.076705,
#   'longitude': -115.089514},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': 37.557637,
#   'longitude': -122.285714},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.799549,
#   'longitude': -122.306571},
#  {'city': 'Los Gatos',
#   'country_code': 'USA',
#   'latitude': 37.222604,
#   'longitude': -121.983814},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 33.945553,
#   'longitude': -118.441219},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 34.064491,
#   'longitude': -118.42749},
#  {'city': 'Berkeley',
#   'country_code': 'USA',
#   'latitude': 37.887864,
#   'longitude': -122.26999},
#  {'city': 'Solana Beach',
#   'country_code': 'USA',
#   'latitude': 33.020832,
#   'longitude': -117.077311},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.789634,
#   'longitude': -122.404052},
#  {'city': 'Salt Lake City',
#   'country_code': 'AFG',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': 37.559287,
#   'longitude': -122.302262},
#  {'city': 'Livermore',
#   'country_code': 'USA',
#   'latitude': 37.661237,
#   'longitude': -121.803572},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': 37.566879,
#   'longitude': -122.323895},
#  {'city': 'Sunnyvale',
#   'country_code': 'USA',
#   'latitude': 37.384239,
#   'longitude': -122.012475},
#  {'city': 'Mountain View',
#   'country_code': 'USA',
#   'latitude': 37.418491,
#   'longitude': -122.08744},
#  {'city': 'Irving',
#   'country_code': 'USA',
#   'latitude': 32.860831,
#   'longitude': -96.9403},
#  {'city': 'Marina del Rey',
#   'country_code': 'USA',
#   'latitude': 33.977854,
#   'longitude': -118.445271},
#  {'city': 'Cambridge',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.779558,
#   'longitude': -122.393041},
#  {'city': 'Reno',
#   'country_code': 'USA',
#   'latitude': 39.530368,
#   'longitude': -119.81439},
#  {'city': 'Sunnyvale',
#   'country_code': 'USA',
#   'latitude': 37.369195,
#   'longitude': -122.036849},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Baltimore',
#   'country_code': 'USA',
#   'latitude': 39.281734,
#   'longitude': -76.581864},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': 51.54236,
#   'longitude': -0.149522},
#  {'city': '',
#   'country_code': 'NZL',
#   'latitude': -37.797384,
#   'longitude': 175.2604},
#  {'city': 'Tel Aviv',
#   'country_code': 'ISR',
#   'latitude': 32.0554,
#   'longitude': 34.7595},
#  {'city': 'Melbourne',
#   'country_code': 'USA',
#   'latitude': 28.074742,
#   'longitude': -80.632606},
#  {'city': 'Mill Valley',
#   'country_code': 'USA',
#   'latitude': 37.904468,
#   'longitude': -122.542491},
#  {'city': 'Singer Island',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Van Nuys',
#   'country_code': 'USA',
#   'latitude': 34.210785,
#   'longitude': -118.474261},
#  {'city': 'Mountain View',
#   'country_code': 'USA',
#   'latitude': 37.401355,
#   'longitude': -122.104099},
#  {'city': 'Needham',
#   'country_code': 'USA',
#   'latitude': 42.304545,
#   'longitude': -71.220187},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.745216,
#   'longitude': -73.982807},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.792262,
#   'longitude': -122.403486},
#  {'city': 'Santa Clara',
#   'country_code': 'USA',
#   'latitude': 37.396312,
#   'longitude': -121.961396},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.603015,
#   'longitude': -122.335668},
#  {'city': 'Wellington',
#   'country_code': 'NZL',
#   'latitude': -41.28648,
#   'longitude': 174.776217},
#  {'city': 'Mountain View',
#   'country_code': 'USA',
#   'latitude': 37.384919,
#   'longitude': -122.053175},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.775196,
#   'longitude': -122.419204},
#  {'city': 'los angeles',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': None,
#   'country_code': 'GBR',
#   'latitude': 55.378051,
#   'longitude': -3.435973},
#  {'city': 'Hayward',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Mountain View',
#   'country_code': 'USA',
#   'latitude': 37.39248,
#   'longitude': -122.072612},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.775196,
#   'longitude': -122.419204},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.733603,
#   'longitude': -122.355579},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': 51.524323,
#   'longitude': -0.081169},
#  {'city': '', 'country_code': 'USA', 'latitude': None, 'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.783898,
#   'longitude': -122.395234},
#  {'city': None,
#   'country_code': 'ISR',
#   'latitude': 31.046051,
#   'longitude': 34.851612},
#  {'city': 'Venice',
#   'country_code': 'USA',
#   'latitude': 34.011335,
#   'longitude': -118.468458},
#  {'city': 'Poughkeepsie',
#   'country_code': 'USA',
#   'latitude': 41.705555,
#   'longitude': -73.938638},
#  {'city': 'Montreuil',
#   'country_code': 'FRA',
#   'latitude': None,
#   'longitude': None},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 45.3085,
#   'longitude': -122.77941},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Secaucus',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': '', 'country_code': 'ISR', 'latitude': None, 'longitude': None},
#  {'city': '',
#   'country_code': 'USA',
#   'latitude': 32.856744,
#   'longitude': -117.20717},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.856331,
#   'longitude': -122.495222},
#  {'city': 'Norderstedt',
#   'country_code': 'DEU',
#   'latitude': 53.707739,
#   'longitude': 10.023246},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 42.349164,
#   'longitude': -71.049346},
#  {'city': 'Boston',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': '',
#   'country_code': 'USA',
#   'latitude': 37.408826,
#   'longitude': -122.29522},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.781159,
#   'longitude': -73.978332},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.443058,
#   'longitude': -122.161674},
#  {'city': 'Mountain View',
#   'country_code': 'USA',
#   'latitude': 37.386175,
#   'longitude': -122.083487},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': None,
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Rotterdam',
#   'country_code': 'NLD',
#   'latitude': 51.9562996,
#   'longitude': 4.5188631},
#  {'city': 'Bellevue',
#   'country_code': 'USA',
#   'latitude': 47.617411,
#   'longitude': -122.191988},
#  {'city': '', 'country_code': 'USA', 'latitude': None, 'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.744274,
#   'longitude': -122.421344},
#  {'city': 'Boston',
# ...
#   'latitude': 47.634444,
#   'longitude': -122.3419},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': '',
#   'country_code': 'USA',
#   'latitude': 38.892914,
#   'longitude': -77.072571},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.680496,
#   'longitude': -122.120938},
#  {'city': 'Bangalore',
#   'country_code': 'IND',
#   'latitude': 12.933644,
#   'longitude': 77.628576},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.707253,
#   'longitude': -74.007413},
#  {'city': 'chicago',
#   'country_code': 'USA',
#   'latitude': 41.955054,
#   'longitude': -87.673059},
#  {'city': 'Milpitas',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Doha',
#   'country_code': 'QAT',
#   'latitude': 25.2948,
#   'longitude': 51.5082},
#  {'city': 'Bekasi',
#   'country_code': 'IDN',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'York',
#   'country_code': 'GBR',
#   'latitude': 53.949714,
#   'longitude': -1.045716},
#  {'city': 'San Diego',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Southampton',
#   'country_code': 'GBR',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Atlanta',
#   'country_code': 'USA',
#   'latitude': 33.7486,
#   'longitude': -84.3884},
#  {'city': 'Gdynia',
#   'country_code': 'POL',
#   'latitude': 54.538851,
#   'longitude': 18.467386},
#  {'city': 'South San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.65466,
#   'longitude': -122.40788},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.7466655,
#   'longitude': -122.4428064},
#  {'city': 'Lantau Island',
#   'country_code': 'HKG',
#   'latitude': 22.266141,
#   'longitude': 113.997909},
#  {'city': 'Wuhan', 'country_code': 'USA', 'latitude': None, 'longitude': None},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.715145,
#   'longitude': -74.005897},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.790032,
#   'longitude': -122.404488},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'East Brunswick',
#   'country_code': 'USA',
#   'latitude': 40.407946,
#   'longitude': -74.411658},
#  {'city': 'Bangalore',
#   'country_code': 'IND',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Brooklyn',
#   'country_code': 'USA',
#   'latitude': 40.684257,
#   'longitude': -73.961981},
#  {'city': 'Cambridge',
#   'country_code': 'USA',
#   'latitude': 42.375392,
#   'longitude': -71.118487},
#  {'city': 'Burnaby',
#   'country_code': 'CAN',
#   'latitude': 49.2604154,
#   'longitude': -123.007518},
#  {'city': 'Chicago',
#   'country_code': 'USA',
#   'latitude': 41.896499,
#   'longitude': -87.643622},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 34.059721,
#   'longitude': -118.425401},
#  {'city': 'Philadelphia',
#   'country_code': 'USA',
#   'latitude': 39.9564403,
#   'longitude': -75.1961715},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.383844,
#   'longitude': -121.918319},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.776467,
#   'longitude': -122.395792},
#  {'city': 'Acton',
#   'country_code': 'USA',
#   'latitude': 42.445825,
#   'longitude': -71.434135},
#  {'city': 'Portland',
#   'country_code': 'USA',
#   'latitude': 45.446475,
#   'longitude': -122.773646},
#  {'city': 'Westminster',
#   'country_code': 'USA',
#   'latitude': 39.89674,
#   'longitude': -105.07359},
#  {'city': 'Linz',
#   'country_code': 'AUT',
#   'latitude': 48.305996,
#   'longitude': 14.285917},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Berlin',
#   'country_code': 'DEU',
#   'latitude': 52.5131826,
#   'longitude': 13.3941489},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.75033,
#   'longitude': -73.968173},
#  {'city': 'Costa Mesa',
#   'country_code': 'USA',
#   'latitude': 33.689171,
#   'longitude': -117.874221},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.7776778,
#   'longitude': -122.3921102},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Orem',
#   'country_code': 'USA',
#   'latitude': 40.32462,
#   'longitude': -111.679755},
#  {'city': 'Toronto',
#   'country_code': 'CAN',
#   'latitude': 43.670233,
#   'longitude': -79.386755},
#  {'city': 'Bellevue',
#   'country_code': 'USA',
#   'latitude': 47.6106,
#   'longitude': -122.1997},
#  {'city': 'San Jose',
#   'country_code': 'USA',
#   'latitude': 37.244187,
#   'longitude': -121.9053},
#  {'city': 'Roseville',
#   'country_code': 'USA',
#   'latitude': 38.744194,
#   'longitude': -121.234636},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.66274,
#   'longitude': -122.300863},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.744837,
#   'longitude': -73.983843},
#  {'city': '',
#   'country_code': 'USA',
#   'latitude': 26.524058,
#   'longitude': -80.064158},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.798853,
#   'longitude': -122.398599},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.634444,
#   'longitude': -122.3419},
#  {'city': 'San Carlos',
#   'country_code': 'USA',
#   'latitude': 37.494965,
#   'longitude': -122.267654},
#  {'city': 'Bangalore',
#   'country_code': 'IND',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Roubaix',
#   'country_code': 'FRA',
#   'latitude': 50.694712,
#   'longitude': 3.165225},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': 51.5220072,
#   'longitude': -0.0766034},
#  {'city': 'Ramat Gan',
#   'country_code': 'ISR',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Bangalore',
#   'country_code': 'IND',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Munich',
#   'country_code': 'DEU',
#   'latitude': 48.124827,
#   'longitude': 11.556452},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': 51.5248598,
#   'longitude': -0.0836311},
#  {'city': 'Hong Kong',
#   'country_code': 'HKG',
#   'latitude': 22.2799907,
#   'longitude': 114.1587983},
#  {'city': 'Paris',
#   'country_code': 'FRA',
#   'latitude': 48.857993,
#   'longitude': 2.381153},
#  {'city': 'Williamsville',
#   'country_code': 'USA',
#   'latitude': 42.9241,
#   'longitude': -78.8144},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.752325,
#   'longitude': -73.988477},
#  {'city': 'Duluth',
#   'country_code': 'USA',
#   'latitude': 33.984004,
#   'longitude': -84.092596},
#  {'city': 'Hamburg',
#   'country_code': 'DEU',
#   'latitude': 53.54598,
#   'longitude': 9.987181},
#  {'city': 'London W1W 6XF',
#   'country_code': 'GBR',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Amsterdam',
#   'country_code': 'NLD',
#   'latitude': 52.365001,
#   'longitude': 4.892903},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.613896,
#   'longitude': -122.3413},
#  {'city': 'Austin',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': '',
#   'country_code': 'CAN',
#   'latitude': 45.4989683,
#   'longitude': -73.5551499},
#  {'city': 'Pasadena',
#   'country_code': 'USA',
#   'latitude': 34.146436,
#   'longitude': -118.153136},
#  {'city': 'Cape Town,Western Cape',
#   'country_code': 'ZAF',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 45.6667514,
#   'longitude': -122.4721542},
#  {'city': 'Shanghai',
#   'country_code': 'CHN',
#   'latitude': 31.222222,
#   'longitude': 121.475},
#  {'city': 'Shanghai',
#   'country_code': 'CHN',
#   'latitude': 31.222222,
#   'longitude': 121.475},
#  {'city': 'Mellieha',
#   'country_code': 'MLT',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Hertzelia',
#   'country_code': 'ISR',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.775196,
#   'longitude': -122.419204},
#  {'city': 'Austin',
#   'country_code': 'USA',
#   'latitude': 30.2672,
#   'longitude': -97.742306},
#  {'city': 'Austin',
#   'country_code': 'USA',
#   'latitude': 30.2672,
#   'longitude': -97.742306},
#  {'city': 'Hannover',
#   'country_code': 'DEU',
#   'latitude': 52.3653872,
#   'longitude': 9.7580413},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.725568,
#   'longitude': -73.998208},
#  {'city': 'Santa Cruz',
#   'country_code': 'USA',
#   'latitude': 36.977905,
#   'longitude': -122.03336},
#  {'city': 'columbus',
#   'country_code': 'USA',
#   'latitude': 39.976837,
#   'longitude': -83.042051},
#  {'city': 'Walnut Creek',
#   'country_code': 'USA',
#   'latitude': 37.909193,
#   'longitude': -122.067065},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': 37.566123,
#   'longitude': -122.323045},
#  {'city': 'Cambridge',
#   'country_code': 'USA',
#   'latitude': 42.369473,
#   'longitude': -71.078843},
#  {'city': 'Tulsa',
#   'country_code': 'USA',
#   'latitude': 36.0592598,
#   'longitude': -95.957865},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.620716,
#   'longitude': -122.347533},
#  {'city': 'Portland',
#   'country_code': 'USA',
#   'latitude': 43.65467,
#   'longitude': -70.262434},
#  {'city': '',
#   'country_code': 'AUS',
#   'latitude': -25.274398,
#   'longitude': 133.775136},
#  {'city': 'Chicago',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': '',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Cincinnati',
#   'country_code': 'USA',
#   'latitude': 39.098753,
#   'longitude': -84.5163108},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 37.125766,
#   'longitude': -84.07986},
#  {'city': 'Mill Valley',
#   'country_code': 'USA',
#   'latitude': 37.905544,
#   'longitude': -122.547445},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.725883,
#   'longitude': -74.006196},
#  {'city': 'Pittsburgh',
#   'country_code': 'USA',
#   'latitude': 40.442796,
#   'longitude': -79.996384},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.7876175,
#   'longitude': -122.4033943},
#  {'city': 'Austin',
#   'country_code': 'USA',
#   'latitude': 30.242865,
#   'longitude': -97.798398},
#  {'city': 'Aurora',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Madison',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Las Vegas',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': 40.7577017,
#   'longitude': -73.9858165},
#  {'city': 'Hollywood',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Los Gatos',
#   'country_code': 'USA',
#   'latitude': 37.25142,
#   'longitude': -121.968687},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 33.988735,
#   'longitude': -118.368871},
#  {'city': 'New York',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Chicago',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Toronto',
#   'country_code': 'CAN',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Sydney',
#   'country_code': 'AUS',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Montreal',
#   'country_code': 'CAN',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Rotterdam',
#   'country_code': 'NLD',
#   'latitude': 51.919413,
#   'longitude': 4.45585},
#  {'city': 'Shanghai',
#   'country_code': 'CHN',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'La Jolla',
#   'country_code': 'USA',
#   'latitude': 32.874543,
#   'longitude': -117.214722},
#  {'city': 'Ladera Ranch',
#   'country_code': 'USA',
#   'latitude': 33.551221,
#   'longitude': -117.632731},
#  {'city': '',
#   'country_code': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891},
#  {'city': 'Tel Aviv',
#   'country_code': 'ISR',
#   'latitude': 32.0554,
#   'longitude': 34.7595},
#  {'city': 'San Jose',
#   'country_code': 'USA',
#   'latitude': 37.332828,
#   'longitude': -121.884399},
#  {'city': 'Austin',
#   'country_code': 'USA',
#   'latitude': 30.379593,
#   'longitude': -97.765313},
#  {'city': 'West Hollywood',
#   'country_code': 'USA',
#   'latitude': 34.090228,
#   'longitude': -118.393843},
#  {'city': 'Scottsdale',
#   'country_code': 'EGY',
#   'latitude': 33.5060338,
#   'longitude': -111.9261618},
#  {'city': 'Bangalore',
#   'country_code': 'IND',
#   'latitude': 35.929723,
#   'longitude': 139.605025},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': 52.4624161,
#   'longitude': 1.696829},
#  {'city': 'Cupertino',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Washington',
#   'country_code': 'USA',
#   'latitude': 38.920066,
#   'longitude': -77.072331},
#  {'city': 'Boston',
#   'country_code': 'USA',
#   'latitude': 42.358283,
#   'longitude': -71.061688},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': 37.446823,
#   'longitude': -122.161523},
#  {'city': 'Beverly Hills',
#   'country_code': 'USA',
#   'latitude': 34.0698494,
#   'longitude': -118.4054182},
#  {'city': 'Fullerton',
#   'country_code': 'USA',
#   'latitude': 33.874609,
#   'longitude': -117.881607},
#  {'city': 'Palo Alto',
#   'country_code': 'USA',
#   'latitude': 37.425168,
#   'longitude': -122.136248},
#  {'city': 'North Miami Beach',
#   'country_code': 'USA',
#   'latitude': 25.929683,
#   'longitude': -80.168256},
#  {'city': '',
#   'country_code': 'CHN',
#   'latitude': 35.86166,
#   'longitude': 104.195397},
#  {'city': '',
#   'country_code': 'ISR',
#   'latitude': 31.046051,
#   'longitude': 34.851612},
#  {'city': 'Millstone Township',
#   'country_code': 'USA',
#   'latitude': 40.219214,
#   'longitude': -74.370313},
#  {'city': 'Bradenton',
#   'country_code': 'USA',
#   'latitude': 27.434873,
#   'longitude': -82.580968},
#  {'city': 'Mumbai',
#   'country_code': 'IND',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.7759675,
#   'longitude': -122.3931128},
#  {'city': 'San Mateo',
#   'country_code': 'USA',
#   'latitude': 37.560781,
#   'longitude': -122.284114},
#  {'city': 'Millstone Township',
#   'country_code': 'USA',
#   'latitude': 40.219214,
#   'longitude': -74.370313},
#  {'city': 'Liverpool',
#   'country_code': 'GBR',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.7862705,
#   'longitude': -122.3975827},
#  {'city': 'Amman', 'country_code': 'JOR', 'latitude': None, 'longitude': None},
#  {'city': 'Seattle',
#   'country_code': 'USA',
#   'latitude': 47.620716,
#   'longitude': -122.347533},
#  {'city': 'Vancouver',
#   'country_code': 'CAN',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Coral Gables',
#   'country_code': 'USA',
#   'latitude': 25.705057,
#   'longitude': -80.271378},
#  {'city': 'Sunnyvale',
#   'country_code': 'USA',
#   'latitude': 37.380941,
#   'longitude': -122.010729},
#  {'city': 'Roswell',
#   'country_code': 'USA',
#   'latitude': 34.016362,
#   'longitude': -84.322687},
#  {'city': 'London',
#   'country_code': 'GBR',
#   'latitude': 51.523676,
#   'longitude': -0.107843},
#  {'city': 'Austin',
#   'country_code': 'USA',
#   'latitude': 30.27646,
#   'longitude': -97.746387},
#  {'city': 'Scotts Valley',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'San Jose',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Los Angeles',
#   'country_code': 'USA',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Palma de Mallorca',
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'city': 'Raleigh',
#   'country_code': 'USA',
#   'latitude': 35.898459,
#   'longitude': -78.650931},
#  {'city': 'San Francisco',
#   'country_code': 'USA',
#   'latitude': 37.775196,
#   'longitude': -122.419204},
#  {'city': 'Allentown',
#   'country_code': 'USA',
#   'latitude': 40.58471,
#   'longitude': -75.588974},
#  ...]

# %%
df= pd.DataFrame(list_cities)

# %%
df.city.value_counts()
# Out:
# San Francisco    419
# New York         378
#                  322
# London           258
# Los Angeles      118
#                 ...
# Harrisonburg       1
# Loveland           1
# Blacksburg         1
# Nairobi            1
# Livingston         1
# Name: city, Length: 1888, dtype: int64

# %%
df
# Out:
#                 city country_code   latitude   longitude
# 0            Seattle          USA  47.603122 -122.333253
# 1           New York          USA  40.723731  -73.996431
# 2         Pleasanton          USA  37.692934 -121.904945
# 3         San Carlos          USA  37.506885 -122.247573
# 4     West Hollywood          USA  34.090368 -118.393064
# ...              ...          ...        ...         ...
# 7631         Bohemia          USA  40.775055  -73.088140
# 7632      Palm Beach          USA  26.705331  -80.041395
# 7633      KÃ¼ssnacht          CHE  47.088219    8.437163
# 7634      Livingston          USA  40.793024  -74.323554
# 7635      Birmingham          USA  33.518885  -86.816068
#
# [7636 rows x 4 columns]

# %%
df['count'] = df.groupby('city')['city'].transform('count')
df
# Out:
#                 city country_code   latitude   longitude  count
# 0            Seattle          USA  47.603122 -122.333253  111.0
# 1           New York          USA  40.723731  -73.996431  378.0
# 2         Pleasanton          USA  37.692934 -121.904945   12.0
# 3         San Carlos          USA  37.506885 -122.247573    7.0
# 4     West Hollywood          USA  34.090368 -118.393064    9.0
# ...              ...          ...        ...         ...    ...
# 7631         Bohemia          USA  40.775055  -73.088140    1.0
# 7632      Palm Beach          USA  26.705331  -80.041395    2.0
# 7633      KÃ¼ssnacht          CHE  47.088219    8.437163    1.0
# 7634      Livingston          USA  40.793024  -74.323554    1.0
# 7635      Birmingham          USA  33.518885  -86.816068   13.0
#
# [7636 rows x 5 columns]

# %%
df.sort_values(by=['count'], ascending = False, inplace= True)
df
# Out:
#                city country_code   latitude   longitude  count
# 1638  San Francisco          USA  37.788457 -122.399884  419.0
# 3907  San Francisco          USA  37.783171 -122.392901  419.0
# 164   San Francisco          USA  37.780883 -122.395257  419.0
# 165   San Francisco          USA        NaN         NaN  419.0
# 4368  San Francisco          USA  37.844803 -122.290897  419.0
# ...             ...          ...        ...         ...    ...
# 754            None          USA  37.090240  -95.712891    NaN
# 755            None          USA  37.090240  -95.712891    NaN
# 763            None          NLD  52.132633    5.291266    NaN
# 769            None          USA  37.090240  -95.712891    NaN
# 6591           None          CHN        NaN         NaN    NaN
#
# [7636 rows x 5 columns]

# %%
df.drop_duplicates(subset = ['city'], inplace = True)
df
# Out:
#                city country_code   latitude   longitude  count
# 1638  San Francisco          USA  37.788457 -122.399884  419.0
# 3793       New York          USA        NaN         NaN  378.0
# 1884                         ISR  31.046051   34.851612  322.0
# 7451         London          GBR  51.517356   -0.103774  258.0
# 747     Los Angeles          USA        NaN         NaN  118.0
# ...             ...          ...        ...         ...    ...
# 4347       Fort Lee          USA        NaN         NaN    1.0
# 7144   Crystal Lake          USA  42.279634  -88.333977    1.0
# 7143       SetÃºbal          PRT        NaN         NaN    1.0
# 4117         Carlow          IRL  52.821340   -6.922036    1.0
# 18             None          USA  37.090240  -95.712891    NaN
#
# [1889 rows x 5 columns]

# %%
df.rename(columns={"country_code": "country"},inplace = True)

# %%
df.reset_index(inplace= True)

# %%
df.drop('index',axis =1, inplace =True)

# %%
df.dropna(subset=['city'], inplace = True)

# %%
df.drop(2, inplace=True)

# %%
df
# Out:
#                city country   latitude   longitude  count
# 0     San Francisco     USA  37.788457 -122.399884  419.0
# 1          New York     USA        NaN         NaN  378.0
# 3            London     GBR  51.517356   -0.103774  258.0
# 4       Los Angeles     USA        NaN         NaN  118.0
# 5           Seattle     USA  47.620716 -122.347533  111.0
# ...             ...     ...        ...         ...    ...
# 1883        Hialeah     USA  25.866642  -80.314220    1.0
# 1884       Fort Lee     USA        NaN         NaN    1.0
# 1885   Crystal Lake     USA  42.279634  -88.333977    1.0
# 1886       SetÃºbal     PRT        NaN         NaN    1.0
# 1887         Carlow     IRL  52.821340   -6.922036    1.0
#
# [1887 rows x 5 columns]

# %% [markdown]
# Query about money
